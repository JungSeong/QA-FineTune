# %% [markdown]
# 참고 : https://zero-ai.tistory.com/62

# %%
import torch

print(f"CUDA 사용 가능 여부: {torch.cuda.is_available()}")
print(f"GPU 이름: {torch.cuda.get_device_name(0)}")
print(f"CUDA 버전: {torch.version.cuda}")
print(f"PyTorch 버전: {torch.version}")
print(f"bf16 지원 여부: {torch.cuda.is_bf16_supported()}")
# Out:
# CUDA 사용 가능 여부: True
# GPU 이름: NVIDIA GB10
# CUDA 버전: 13.0
# PyTorch 버전: <module 'torch.version' from '/home/vsc/LLM_TUNE/myenv/lib/python3.12/site-packages/torch/version.py'>
# bf16 지원 여부: True
# /home/vsc/LLM_TUNE/myenv/lib/python3.12/site-packages/torch/cuda/__init__.py:435: UserWarning:
#     Found GPU0 NVIDIA GB10 which is of cuda capability 12.1.
#     Minimum and Maximum cuda capability supported by this version of PyTorch is
#     (8.0) - (12.0)
#
#   queued_call()

# %%
from datasets import Dataset
import pandas as pd
import glob

file_path = glob.glob("./data/*.xlsx")
dfs = [pd.read_excel(file) for file in file_path]
combined_df = pd.concat(dfs, ignore_index=True)
dataset = Dataset.from_pandas(combined_df)

print(dataset)
print(dataset[0])
# Out:
# Dataset({
#     features: ['FAQ', 'TITLE', 'DES'],
#     num_rows: 362
# })
# {'FAQ': 1, 'TITLE': '회원증을 대리발급 할 수 있나요?', 'DES': '회원증 대리발급은 만14세 미만 아동, 만65세 이상 어르신, 장애인, 임산부만 가능하며 아래 구비서류를 지참하여 대리인이 방문 시 대리발급이 가능합니다.\n\n· 대상 : 만14세 미만 아동, 만65세 이상 어르신, 장애인, 임산부\n· 구비서류\n\xa0 - 공통 : ①위임자 신분증, ②피위임자(대리인) 신분증\n\xa0 - 장애인 : 장애인 복지카드 또는 장애인 증명서\n\xa0 - 임신부 : 산모수첩 / 산모 : 주민등록등본(출산 후 12개월까지)\n· 방법 : 홈페이지 회원가입 후 위 항목의 해당하는 구비서류를 지참하여 피위임자(대리인)이 도서관 방문'}

# %%
# 데이터 증강을 위해 로컬 EXAONE-3.5-7.8B-Instruct 모델 사용

# %%
from transformers import (
    AutoTokenizer, 
    AutoModelForCausalLM,
    BitsAndBytesConfig, 
    TrainingArguments,
)
from datasets import Dataset
import os, torch, json, wandb, subprocess
from sklearn.model_selection import train_test_split
import torch.nn as nn
from peft import (
    get_peft_model,
    LoraConfig, 
    TaskType,
    prepare_model_for_kbit_training
)

# %%
quantization_config = BitsAndBytesConfig(
    load_in_4bit=True, # 모델 가중치를 4bit로 불러오기
    bnb_4bit_compute_dtype=torch.bfloat16, #bfloat16 or float16
    bnb_4bit_quant_type="nf4", # nf4 or fp4
)

# %%
model_id = "/home/vsc/LLM/model/EXAONE-3.5-7.8B-Instruct"

model = AutoModelForCausalLM.from_pretrained(
    model_id,
    torch_dtype=torch.bfloat16,
    trust_remote_code=True,
    quantization_config=quantization_config,
    device_map="auto"
)
tokenizer = AutoTokenizer.from_pretrained(model_id)
# Out:
# Loading checkpoint shards:   0%|          | 0/7 [00:00<?, ?it/s]

# %%
import pandas as pd
from transformers import pipeline

pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    torch_dtype=torch.bfloat16,
    device_map="auto",
)

# %%
def generate_augmented_data(faq_content):
    system_message = (
        "당신은 도서관 FAQ 데이터를 바탕으로 자연스러운 대화형 학습 데이터를 생성하는 전문가입니다.\n"
        "제공된 정보를 분석하여 다음 4가지 유형의 데이터를 생성하세요. 각 유형별로 최소 3개씩, 총 12개의 예시를 만드세요.\n\n"
        "이때 판단이 쉬운 예시와 보통, 어려운 예시 총 3가지 상황을 가정하세요."
        
        "### [답변 가이드라인]\n"
        "1. **label: 'yes' (긍정 확인)**\n"
        "   - 문구: '네, 가능합니다! 도서관 규정에 따르면...'\n"
        "   - 활용: 질문의 조건이 FAQ와 일치할 때 사용.\n"
        "2. **label: 'no' (부정/제한)**\n"
        "   - 문구: '죄송하지만 어렵습니다. 그 이유는...'\n"
        "   - 활용: 질문의 조건이 FAQ 규정에 어긋날 때 사용. '사실과 다르다'는 표현 대신 '규정상 어렵다'를 사용하세요.\n"
        "3. **label: 'info' (단순 정보 제공)**\n"
        "   - 문구: '문의하신 내용에 대해 안내해 드리겠습니다. 관련 서류는...'\n"
        "   - 활용: 네/아니오 판단이 아닌 정보 질문에 사용.\n"
        "4. **label: 'false' (판단 불가)**\n"
        "   - 문구: '죄송합니다. 현재 제공된 정보만으로는 해당 내용을 확인하기 어렵습니다.'\n"
        "   - 활용: FAQ에 없는 내용이거나 질문이 모호할 때 사용.\n\n"
        "모든 답변은 실제 도서관 사서가 방문객에게 설명하듯 친절하고 자연스러운 문장으로 작성하세요."
        "판단 불가의 경우 문구 외에 다른 문장은 생성하지 마세요."
        "JSON 답변 외에 다른 문장은 일체 생성하지 마세요."
    )

    # 사용자가 정의한 user_content
    user_content = f"""
    [도서관 FAQ 정보]
    {faq_content}
    
    위 정보를 바탕으로 질문과 답변이 논리적으로 완벽하게 이어지는 JSON 데이터를 생성하세요.
    
    [출력 예시]:
    [
      {{"question": "임산부인데 남편이 대신 발급받을 수 있나요?", "answer": "네, 가능합니다! 도서관 규정에 따르면 임산부의 경우 대리 발급 대상에 포함됩니다.", "label": "yes"}},
      {{"question": "성인 직장인인데 친구가 대신 가도 되나요?", "answer": "죄송하지만, 해당 조건으로는 대리 발급이 어렵습니다. 대리 발급은 아동, 어르신, 장애인, 임산부로 대상이 제한되어 있기 때문입니다.", "label": "no"}},
      {{"question": "장애인 대리 발급 시 어떤 서류가 필요한가요?", "answer": "문의하신 내용에 대해 안내해 드리겠습니다. 장애인 복지카드 또는 장애인 증명서를 지참하시면 됩니다.", "label": "info"}},
      {{"question": "죄송합니다. 현재 제공된 정보만으로는 해당 내용을 확인하기 어렵습니다.", "label": "false"}}
    ]
    """
    
    messages = [
        {"role": "system", "content": system_message},
        {"role": "user", "content": user_content},
    ]

    prompt = tokenizer.apply_chat_template(
        messages, 
        tokenize=False, 
        add_generation_prompt=True
    )

    outputs = pipe(
        prompt, 
        max_new_tokens=2048, 
        do_sample=True, 
        temperature=0.7,
        truncation=True,
        eos_token_id=tokenizer.eos_token_id
    )

    # 생성된 텍스트 추출 (결과값만 깔끔하게 가져오기 위해 prompt 이후 내용만 슬라이싱)
    full_text = outputs[0]["generated_text"]
    response = full_text.split("[|assistant|]")[-1].strip()
    
    return response

# %%
print(dataset[1]["DES"])
generate_augmented_data(dataset[1]["DES"])
# Out:
# 가족회원이란, 고양시 도서관 정회원으로 가입 후 가족회원으로 등록 시 가족명의로 도서대출·도서예약·상호대차 동일하게 이용가능한 서비스입니다.
# ※ 가족명의 이용 시 자료실 안내데스크에 반드시 본인 회원증을 제시하여야 함(가족 회원증으로 대출 불가)
# 가족회원 등록방법
# 가족구성원 모두 정회원 가입 후 가족임을 증명할 수 있는 서류(주민등록등본 또는 가족관계증명서) 지참하여 도서관 방문
# '```json\n[\n  {\n    "question": "가족회원으로 등록하려면 가족관계증명서 외에 다른 증빙서류가 가능한가요?",\n    "answer": "네, 가능합니다! 도서관 규정에 따르면 가족임을 증명할 수 있는 서류는 주민등록등본이나 가족관계증명서 외에도 다양한 서류가 인정될 수 있습니다. 자세한 내용은 도서관 사서에게 문의해 주시기 바랍니다.",\n    "label": "yes"\n  },\n  {\n    "question": "초등학생 자녀와 제가 함께 정회원으로 가입해야 가족회원 혜택을 받을 수 있나요?",\n    "answer": "네, 맞습니다. 가족회원 혜택을 받기 위해서는 가족 구성원 모두가 고양시 도서관 정회원으로 가입해야 합니다. 초등학생 자녀와 함께 정회원 가입 후 가족임을 증명하는 서류를 제출하면 가족회원 등록이 가능합니다.",\n    "label": "yes"\n  },\n  {\n    "question": "남편과 함께 도서관에 왔는데, 남편 이름으로 도서를 대출받을 수 있나요?",\n    "answer": "죄송하지만 어렵습니다. 가족회원은 가족 구성원 모두의 이름으로 도서 대출이 가능하지만, 본인의 회원증을 제시해야 합니다. 남편 이름으로 대출은 불가능합니다. 가족회원증으로는 대출이 불가능합니다.",\n    "label": "no"\n  },\n  {\n    "question": "가족회원 등록 시 필요한 서류 종류가 궁금합니다.",\n    "answer": "문의하신 내용에 대해 안내해 드리겠습니다. 가족회원 등록 시 필요한 서류는 주민등록등본, 가족관계증명서 등 가족임을 증명할 수 있는 서류입니다. 자세한 내용은 도서관 웹사이트나 사서에게 문의하시기 바랍니다.",\n    "label": "info"\n  },\n  {\n    "question": "부모님과 함께 회원증을 만들러 왔습니다. 부모님도 가족회원으로 함께 이용할 수 있나요?",\n    "answer": "네, 가능합니다! 부모님께서 모두 고양시 도서관 정회원으로 가입하신 후 가족관계증명서 등 가족임을 증명하는 서류를 제출하시면 부모님도 가족회원으로 등록하여 같은 혜택을 누릴 수 있습니다.",\n    "label": "yes"\n  },\n  {\n    "question": "가족회원인데, 자료실에서 책을 빌릴 때 본인 회원증 외에 가족회원증도 사용 가능한가요?",\n    "answer": "죄송하지만 어렵습니다. 가족회원증으로는 도서 대출이 불가능합니다. 자료실 이용 시 본인 회원증을 제시해야 합니다.",\n    "label": "no"\n  },\n  {\n    "question": "대학생인데, 부모님과 함께 가족회원으로 등록할 수 있나요?",\n    "answer": "죄송하지만 어렵습니다. 가족회원 등록은 아동, 어르신, 장애인, 임산부 등 특정 대상에게만 허용됩니다. 대학생의 경우 해당 대상에 포함되지 않습니다.",\n    "label": "no"\n  },\n  {\n    "question": "가족회원 등록 과정에서 어려움을 겪고 있습니다. 도움을 주실 수 있나요?",\n    "answer": "문의하신 내용에 대해 안내해 드리겠습니다. 도서관 웹사이트에 자세한 가족회원 등록 안내가 있습니다. 또는 도서관 사서에게 직접 문의하시면 자세한 도움을 드릴 수 있습니다.",\n    "label": "info"\n  },\n  {\n    "question": "현재 거주 지역이 고양시가 아닌데요. 가족회원으로 도서관을 이용할 수 있나요?",\n    "answer": "죄송합니다. 현재 제공된 정보만으로는 해당 내용을 확인하기 어렵습니다. 이용 지역에 대한 제한 사항은 도서관 정책 변경에 따라 달라질 수 있으므로 도서관에 직접 문의하시는 것이 가장 정확한 정보를 얻는 방법입니다.",\n    "label": "false"\n  },\n  {\n    "question": "가족회원 혜택이 어떤 것들이 있나요 자세히 알려주세요.",\n    "answer": "문의하신 내용에 대해 안내해 드리겠습니다. 가족회원 혜택은 주로 도서 대출 한도 확대, 자료실 이용 혜택 등이 포함됩니다. 자세한 혜택 내용은 도서관 웹사이트나 사서에게 문의하시면 자세히 알려드릴 수 있습니다.",\n    "label": "info"\n  },\n  {\n    "question": "가족회원으로 등록하려면 필요한 서류를 미리 준비해야 하나요?",\n    "answer": "네, 가능합니다! 가족회원 등록 시 가족임을 증명할 수 있는 서류(주민등록등본 또는 가족관계증명서 등)를 미리 준비하시는 것이 좋습니다. 방문 시 편리하게 등록 절차를 진행할 수 있습니다.",\n    "label": "yes"\n  },\n  {\n    "question": "가족회원 등록 시 아이들의 연령 제한이 있나요?",\n    "answer": "죄송하지만 어렵습니다. 가족회원 등록 과정에서 아이들의 연령 제한은 명시되어 있지 않습니다. 하지만 모든 가족 구성원이 고양시 도서관 정회원으로 가입되어야 합니다. 자세한 내용은 도서관에 문의해 주시기 바랍니다.",\n    "label": "no"\n  },\n  {\n    "question": "가족회원 혜택에 대해 좀 더 자세히 설명해 주실 수 있나요?",\n    "answer": "문의하신 내용에 대해 안내해 드리겠습니다. 가족회원 혜택은 주로 도서 대출 한도 확대와 같은 서비스 혜택을 포함합니다. 정확한 혜택 내용은 도서관 웹사이트나 직접 도서관 사서에게 문의하시면 자세히 안내받으실 수 있습니다.",\n    "label": "info"\n  }\n]\n```'

# %%
print(type(dataset))
print(dataset.select(range(5)))
# Out:
# <class 'datasets.arrow_dataset.Dataset'>
# Dataset({
#     features: ['FAQ', 'TITLE', 'DES'],
#     num_rows: 5
# })

# %%
import json
import re
import pandas as pd

def parse_generated_json(response_text):
    try:
        # 1. 마크다운 코드 블록 제거 (```json ... ``` 사이의 내용만 추출)
        json_pattern = re.compile(r"```json\s*(.*?)\s*```", re.DOTALL)
        match = json_pattern.search(response_text)
        
        if match:
            json_str = match.group(1)
        else:
            json_str = response_text.strip()
            
        # 2. JSON 문자열을 파이썬 리스트로 변환
        data_list = json.loads(json_str)
        return data_list
    except Exception as e:
        print(f"파싱 에러 발생: {e}")
        return []

# %%
all_augmented_data = []

for i, row in enumerate(dataset):
    print(f"[{i+1}/{len(dataset)}] 증강 진행 중: {row['TITLE']}")
    
    # 1. 모델로부터 텍스트 생성
    raw_output = generate_augmented_data(row["DES"])
    
    # 2. 파싱하여 리스트로 변환
    parsed_list = parse_generated_json(raw_output)
    
    for item in parsed_list:
        item['faq'] = row['FAQ'] 
        item['title'] = row['TITLE'] 
        all_augmented_data.append(item)

# 4. 최종 결과 저장
final_df = pd.DataFrame(all_augmented_data)
final_df.to_json("augmented_library_faq.jsonl", orient='records', force_ascii=False, lines=True)

print(f"✅ 총 {len(final_df)}개의 학습 데이터 생성 완료!")
# Out:
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# [1/362] 증강 진행 중: 회원증을 대리발급 할 수 있나요?
# [2/362] 증강 진행 중: 가족회원이 무엇인가요?
# ✅ 총 25개의 학습 데이터 생성 완료!
