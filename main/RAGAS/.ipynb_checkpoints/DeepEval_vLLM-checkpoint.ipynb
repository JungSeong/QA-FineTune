# %%
# !uv pip list | grep deepeval
# !uv pip list | grep langchain
# Out:
# Using Python 3.12.3 environment at: /home/vsc/LLM_TUNE/QA-FineTune/venv/venv-RAG
# deepeval                                 3.7.0
# Using Python 3.12.3 environment at: /home/vsc/LLM_TUNE/QA-FineTune/venv/venv-RAG
# langchain                                1.2.10
# langchain-classic                        1.0.1
# langchain-community                      0.4.1
# langchain-core                           1.2.17
# langchain-huggingface                    1.2.1
# langchain-openai                         0.1.7
# langchain-text-splitters                 1.1.1

# %%
import os
import nest_asyncio
nest_asyncio.apply()

# %%
import pandas as pd

XLSX_PATH = "/home/vsc/LLM_TUNE/QA-FineTune/main/data/고양시도서관 FAQ1.xlsx"
TXT_PATH  = "/home/vsc/LLM_TUNE/QA-FineTune/main/data/고양시도서관_FAQ1.txt"

df = pd.read_excel(XLSX_PATH)
print("컬럼:", df.columns.tolist())
print(f"행 수: {len(df)}")
# df.head(3)   # 주피터라면 표시

# 실제 컬럼명으로 바꾸세요 (당신의 파일 기준으로)
TITLE = df.columns[1]   # 예: '질문' 또는 '제목'
DES   = df.columns[2]   # 예: '답변' 또는 '내용'

with open(TXT_PATH, "w", encoding="utf-8") as f:
    for _, row in df.iterrows():
        q = str(row[TITLE]).strip()
        a = str(row[DES]).strip()
        if q and a and q != "nan" and a != "nan":
            f.write(f"Q: {q}\nA: {a}\n\n")

# 파일 확인
with open(TXT_PATH, encoding="utf-8") as f:
    content = f.read()
print(f"저장 완료: {TXT_PATH}")
print(f"파일 크기: {len(content)} 글자")
print("-" * 40)
print(content[:400])
# Out:
# 컬럼: ['FAQ', 'TITLE', 'DES']
# 행 수: 110
# 저장 완료: /home/vsc/LLM_TUNE/QA-FineTune/main/data/고양시도서관_FAQ1.txt
# 파일 크기: 20562 글자
# ----------------------------------------
# Q: 회원증을 대리발급 할 수 있나요?
# A: 회원증 대리발급은 만14세 미만 아동, 만65세 이상 어르신, 장애인, 임산부만 가능하며 아래 구비서류를 지참하여 대리인이 방문 시 대리발급이 가능합니다.
#
# · 대상 : 만14세 미만 아동, 만65세 이상 어르신, 장애인, 임산부
# · 구비서류
#   - 공통 : ①위임자 신분증, ②피위임자(대리인) 신분증
#   - 장애인 : 장애인 복지카드 또는 장애인 증명서
#   - 임신부 : 산모수첩 / 산모 : 주민등록등본(출산 후 12개월까지)
# · 방법 : 홈페이지 회원가입 후 위 항목의 해당하는 구비서류를 지참하여 피위임자(대리인)이 도서관 방문
#
# Q: 가족회원이 무엇인가요?
# A: 가족회원이란, 고양시 도서관 정회원으로 가입 후 가족회원으로 등록 시 가족명의로 도서대출·도서예약

# %%
import os
from openai import OpenAI, AsyncOpenAI
from deepeval.models import DeepEvalBaseLLM, DeepEvalBaseEmbeddingModel
from deepeval.synthesizer import Synthesizer
from deepeval.synthesizer.config import ContextConstructionConfig
from typing import List

# 1. 더미 키 설정 (vLLM 우회용)
os.environ["OPENAI_API_KEY"] = "vllm-dummy"

# 2. 커스텀 LLM (Generation)
class VLLMModel(DeepEvalBaseLLM):
    def __init__(self, model_name: str, base_url: str):
        self.model_name = model_name
        self.client = OpenAI(base_url=base_url, api_key="vllm-dummy")
        self.async_client = AsyncOpenAI(base_url=base_url, api_key="vllm-dummy")

    def load_model(self):
        return self.client

    def get_model_name(self):
        return self.model_name

    def generate(self, prompt: str) -> str:
        resp = self.client.chat.completions.create(
            model=self.model_name,
            messages=[{"role": "user", "content": prompt}],
            temperature=0.7,          # 원하면 조정
            max_tokens=512
        )
        return resp.choices[0].message.content

    async def a_generate(self, prompt: str) -> str:
        resp = await self.async_client.chat.completions.create(
            model=self.model_name,
            messages=[{"role": "user", "content": prompt}],
            temperature=0.7,
            max_tokens=2048
        )
        return resp.choices[0].message.content

# 3. 커스텀 Embedding
class VLLMEmbedding(DeepEvalBaseEmbeddingModel):
    def __init__(self, model_name: str, base_url: str):
        self.model_name = model_name
        self.client = OpenAI(base_url=base_url, api_key="vllm-dummy")

    def load_model(self):
        return self.client

    def get_model_name(self):
        return self.model_name

    def embed_text(self, text: str) -> List[float]:
        resp = self.client.embeddings.create(input=text, model=self.model_name)
        return resp.data[0].embedding

    def embed_texts(self, texts: List[str]) -> List[List[float]]:
        resp = self.client.embeddings.create(input=texts, model=self.model_name)
        return [d.embedding for d in resp.data]

    async def a_embed_text(self, text: str) -> List[float]:
        embedding_model = self.load_model()
        return await embedding_model.aembed_query(text)

    async def a_embed_texts(self, texts: List[str]) -> List[List[float]]:
        embedding_model = self.load_model()
        return await embedding_model.aembed_documents(texts)

# %%
# ────────────────────────────────────────────────
# 인스턴스 생성 (당신의 vLLM 포트 그대로)
local_llm = VLLMModel(
    model_name="/models/Exaone-3.5-32B-Instruct",
    base_url="http://localhost:8002/v1"
)

local_embedder = VLLMEmbedding(
    model_name="/embeddings/dragonkue/snowflake-arctic-embed-l-v2.0-ko",
    base_url="http://localhost:8003/v1"
)

# print(local_llm.generate("ㅎㅇ"))

# 단일 텍스트 임베딩 테스트
single_embedding = local_embedder.embed_text("회원증을 대리발급 할 수 있나요?")
print("단일 임베딩 길이:", len(single_embedding))
print("첫 5개 값:", single_embedding[:5])  # 숫자 배열이 나오면 성공

# 여러 텍스트 배치 테스트
batch_embeddings = local_embedder.embed_texts([
    "회원증을 대리발급 할 수 있나요?",
    "가족회원이 무엇인가요?",
    "도서 대출 기간은 얼마나 되나요?"
])
print("배치 결과 개수:", len(batch_embeddings))
print("각 임베딩 길이:", [len(e) for e in batch_embeddings])
# Out:
# 단일 임베딩 길이: 1024
# 첫 5개 값: [0.015615975484251976, -0.06612725555896759, -0.003962401766330004, -0.010326542891561985, -0.03276457637548447]
# 배치 결과 개수: 3
# 각 임베딩 길이: [1024, 1024, 1024]

# %%
synthesizer = Synthesizer(
    model=local_llm
)

with open(TXT_PATH, encoding="utf-8") as f:
    full_text = f.read().strip()  # 전체 내용 로드 (약 20k자 → 문제없음)

def split_faq(text, chunk_size=2500):  # 문자 기준 5000자 ≈ 2500~3000 토큰
    lines = text.split('\n\n')
    chunks = []
    current = ""
    for line in lines:
        if len(current) + len(line) > chunk_size:
            chunks.append(current.strip())
            current = line + '\n\n'
        else:
            current += line + '\n\n'
    if current:
        chunks.append(current.strip())
    return chunks

chunks = split_faq(full_text, chunk_size=2500)

# %%
print(len(chunks[0]))
# Out:
# 2422

# %%
print("chunks 타입:", type(chunks))
print("chunks 길이:", len(chunks))
print("첫 번째 chunk 타입:", type(chunks[0]) if chunks else "빈 리스트")
print("첫 번째 chunk 길이:", len(chunks[0]) if chunks else 0)
print("첫 번째 chunk 미리보기:", chunks[0][:100] if chunks else "없음")

if not chunks or not isinstance(chunks, list) or not all(isinstance(c, str) for c in chunks):
    raise ValueError("chunks가 올바른 list[str] 형식이 아닙니다!")
# Out:
# chunks 타입: <class 'list'>
# chunks 길이: 9
# 첫 번째 chunk 타입: <class 'str'>
# 첫 번째 chunk 길이: 2422
# 첫 번째 chunk 미리보기: Q: 회원증을 대리발급 할 수 있나요?
# A: 회원증 대리발급은 만14세 미만 아동, 만65세 이상 어르신, 장애인, 임산부만 가능하며 아래 구비서류를 지참하여 대리인이 방문 시 대

# %%
safe_contexts = [str(chunk).strip() for chunk in chunks if str(chunk).strip()]

# %%
goldens = synthesizer.generate_goldens_from_contexts(
    contexts=safe_contexts,                   # 전체를 하나의 context로
    source_files=["고양시도서관_FAQ1.txt"] * len(chunks),  # optional, 추적용
    include_expected_output=True,
    max_goldens_per_context=3,              # 1 context당 최대 8개 golden 목표 (5~15개 정도 기대)
)
# Out:
# Output()
# Exception in callback Task.__step()
# handle: <Handle Task.__step()>
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
# RuntimeError: cannot enter context: <_contextvars.Context object at 0xf3fa3dbce200> is already entered
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
# 생성된 golden 리스트 확인
print("생성된 golden 개수:", len(synthesizer.synthetic_goldens))

# 첫 번째 golden 내용 전체 보기
if synthesizer.synthetic_goldens:
    first_golden = synthesizer.synthetic_goldens[0]
    print("\n=== 첫 번째 Golden 상세 ===")
    print("Input (질문):", first_golden.input)
    print("Expected Output (예상 답변):", first_golden.expected_output)
    print("Context (참조 문맥):", first_golden.context)  # 이제 list[str]로 나와야 함
    print("Source File:", first_golden.source_file)
    print("Additional Metadata:", first_golden.additional_metadata)
else:
    print("아직 golden이 생성되지 않았습니다.")
# Out:
# 생성된 golden 개수: 27
#
# === 첫 번째 Golden 상세 ===
# Input (질문): 무인예약대출은 신원, 화정어린이, 행신어린이, 마두, 식사, 덕이, 주엽어린이도서관에서만 이용 가능하며, 이들 중 어느 곳의 서비스를 이용할 수 있나?
# Expected Output (예상 답변): 무인예약대출 서비스는 신원, 화정어린이, 행신어린이, 마두, 식사, 덕이, 주엽어린이도서관에서 모두 이용 가능합니다. 특정 도서관을 선택하실 경우, 개인의 편의나 위치에 따라 어느 곳을 이용하셔도 됩니다.
# Context (참조 문맥): ['- 신청권수 및 대출기간 : 1인 2권 14일 (7일 연장 가능)\n- 신청시간 : 당일 15시까지 신청된 도서를 취합하여 기기에 투입(휴관일 신청도서의 경우 개관일에 투입)\n- 투입시간 : 16시까지 기기투입 -> 신청자에게 알림톡(SMS) 자동 전송 (알림톡 수신 후 방문)\n- 보관기간 : 도서 투입 후 3일간\n- 신청자의 도서관 회원증으로 대출 가능\n- 이용제한 : 6권 미대출시 1개월간 이용정지\n- 도서관 홈페이지(모바일 포함), 리브로피아를 통한 신청 접수\n- 무인예약서비스 운영 도서관 : 신원, 화정어린이, 행신어린이, 마두, 식사, 덕이, 주엽어린이도서관\n\n홈페이지로그인 →도서검색→무인예약대출신청→도서투입 및 SMS수신→도서대출→도서반납\n순으로 이루어집니다."\n\nQ: 지하철역 아무 곳에서나 반납 가능한가요?\nA: 고양시 11개 지하철역에 설치된 무인반납함에 도서 반납 가능합니다._x000D_\n>(대화역, 마두역, 백마역, 백석역, 삼송역, 원당역, 일산역, 주엽역, 지축역, 행신역, 화정역)\n_x000D_\n※ 별꿈도서관 및 작은도서관, 스마트도서관 제외_x000D_\n※ DVD, 책꾸러미 제외_x000D_\n※ 투입한 당일에 즉시 수거 및 반납되지 않으며 반납완료에 1~4일 소요될 수 있음_x000D_\n※ 반납완료 전 연체 발생할 수 있으므로, 즉시 도서대출이 필요할 경우 시립도서관에 직접 반납\n\nQ: 타관반납에 대해 알고싶어요.\nA: 도서를 소장한 도서관이 아니더라도 모든 시립도서관에 반납 가능합니다._x000D_\n※ 별꿈도서관 및 작은도서관, 스마트도서관 제외 ※ DVD, 책꾸러미 제외\n\nQ: 도서 반납 연기와 도서 연체 시 어떻게 하나요?\nA: 반납연기는 홈페이지-나의도서관에서 1회에 한하여 7일동안 연기 가능합니다._x000D_\n또한, 연체 시 연체일 수 기간만큼 대출정지됩니다. (연체일 중 가장 긴 연체일 적용)_x000D_\n_x000D_\n※ 고양시 관내 하나의 도서관에서 연체가 되면 다른 도서관에서도 대출하실 수 없습니다.\u200b\n\nQ: 대출한 책을 분실하거나 파손한 경우 어떻게 하나요?\nA: 분실, 파손 도서는 동일도서로 구입하여 변상하여야 합니다. _x000D_\n절판, 품절 등의 문제로 구입이 불가능 할 경우에는 도서관으로 연락주시면 담당사서가 지정해주는 유사도서로 구입하여 변상하실 수 있습니다._x000D_\n\nQ: 도서 대출권수와 대출기간은?\nA: 한 번의 회원가입으로 고양시 19개 시립도서관 및 17개 공립작은도서관에서 대출이 가능합니다._x000D_\n대출권수는 1인 최대 25권이며 1관당 7권 이내입니다._x000D_\n대출기간은 14일(2주)이며, 1회 연기(7일) 가능하여 최대 21일까지입니다._x000D_\n시립도서관 도서반납은 18개 시립도서관 및 지하철 무인반납함에 반납이 가능하며 공립작은도서관, 별꿈도서관은 해당 도서관으로 반납하여야 합니다._x000D_\n_x000D_\n※ 지하철 무인반납함 : 3호선(화정, 원당, 삼송, 대화, 백석, 주엽, 마두, 지축) 및 경의선(일산, 행신)에 설치\n\nQ: E-BOOK 리더기(크레마)에서 YES24 서비스가 안되는 경우\nA: 1. 예스24 전자도서관 시스템 개편(2023년 7월 中) 으로 인해, 크레마 단말기에서도 신규 어플을 통해 접속을 해야 합니다._x000D_\n  (단, 크레마 터치, 샤인, 카르타, 카르타 플러스, 사운드 단말기는 지원이 종료가 되었습니다. _x000D_\n   해당 단말기는 신규시스템을 지원하지 않아 불가피하게 지원이 종료가 되었습니다.)_x000D_\n_x000D_\n2. 크레마 단말기 신규어플 설치 방법_x000D_\n 1) 기존과 같이 전자도서관 메뉴에서 고양시도서관센터를 검색 합니다._x000D_\n_x000D_ 2) 고양시도서관센터 명칭 옆에 리뉴얼도서관 버튼을 선택합니다._x000D_\n   - 리뉴얼도서관 명칭이 보이지 않을 경우 상단 즐겨찾기 옆의 새로고침 버튼을 누르시면 됩니다._x000D_\n   - 새로고침 버튼이 보이지 않을 경우, 단말기의 펌웨어 및 앱 업데이트를 합니다. _x000D_\n 3) 리뉴얼도서관 버튼을 누르고 "예"를 선택한 후 다운받을 애플리케이션에서 "인터넷"을 선택합니다._x000D_\n   - 인터넷 화면이 잠깐 나타났다가 사라지게 되고 어플이 다운로드 되어 집니다.  _x000D_\n4) 다운로드된 어플은 [ 열린서재 ]  또는[ + ] 버튼을 통해 설치가 가능 합니다._x000D_\n   - 열린서재가 있는 단말기의 경우, 열린서재 내의 + 버튼을 누르시면 어플을 설치할 수 있습니다._x000D_\n   - 열린서재가 없는 단말기의 경우, 홈화면의 [ + ] 버튼을 누르시면 어플 설치가 가능합니다._x000D_\n5) 설치된 어플은 _x000D_\n   - 열린서재가 있는 단말기는 열린서재 메뉴 내에서_x000D_\n   - 열린서재가 없는 단말기는 홈화면에 추가된 전자도서관 메뉴를 통해서 접속이 가능합니다._x000D_\n_x000D_ 6) 신규어플 실행 하고, 고양시도서관센터 검색 후 도서관 계정으로 로그인 하실 수 있습니다.']
# Source File: 고양시도서관_FAQ1.txt
# Additional Metadata: {'evolutions': ['Constrained'], 'synthetic_input_quality': 0.7}

# %%
import os

save_dir = "./synthetic_data"
os.makedirs(save_dir, exist_ok=True)

# JSON으로 저장 (가장 추천)
synthesizer.save_as(file_type='json', directory=save_dir)
print(f"JSON 저장 완료: {save_dir}/synthetic_goldens.json")

# 또는 CSV로 저장 (필요시)
synthesizer.save_as(file_type='csv', directory=save_dir)
print(f"CSV 저장 완료: {save_dir}/synthetic_goldens.csv")
# Out:
# Synthetic goldens saved at ./synthetic_data/20260303_212430.json!
# JSON 저장 완료: ./synthetic_data/synthetic_goldens.json
# Synthetic goldens saved at ./synthetic_data/20260303_212430.csv!
# CSV 저장 완료: ./synthetic_data/synthetic_goldens.csv

# %%
# MultiContext, Reasoning 질의-응답 생성

# %%
# 2. 커스텀 LLM (Generation)
class VLLMModel(DeepEvalBaseLLM):
    def __init__(self, model_name: str, base_url: str):
        self.model_name = model_name
        self.client = OpenAI(base_url=base_url, api_key="vllm-dummy")
        self.async_client = AsyncOpenAI(base_url=base_url, api_key="vllm-dummy")

    def load_model(self):
        return self.client

    def get_model_name(self):
        return self.model_name

    def generate(self, prompt: str, schema=None, **kwargs):
        res = self.client.chat.completions.create(
            model=self.model_name,
            messages=[{"role": "user", "content": prompt}],
            temperature=0
        )
        output = res.choices[0].message.content.strip()

        # --- JSON 추출 마법 (이게 핵심입니다) ---
        # 1. ```json { ... } ``` 형태에서 내용만 추출
        json_match = re.search(r"(\{.*\}|\[.*\])", output, re.DOTALL)
        if json_match:
            output = json_match.group(1)
        return resp.choices[0].message.content

    async def a_generate(self, prompt: str, **kwargs):
        res = await self.async_client.chat.completions.create(
            model=self.model_name,
            messages=[{"role": "user", "content": prompt}],
            temperature=0
        )
        return res.choices[0].message.content

# 3. 커스텀 Embedding
class VLLMEmbedding(DeepEvalBaseEmbeddingModel):
    def __init__(self, model_name: str, base_url: str):
        self.model_name = model_name
        self.client = OpenAI(base_url=base_url, api_key="vllm-dummy")

    def load_model(self):
        return self.client

    def get_model_name(self):
        return self.model_name

    def embed_text(self, text: str) -> List[float]:
        resp = self.client.embeddings.create(input=text, model=self.model_name)
        return resp.data[0].embedding

    def embed_texts(self, texts: List[str]) -> List[List[float]]:
        resp = self.client.embeddings.create(input=texts, model=self.model_name)
        return [d.embedding for d in resp.data]

    async def a_embed_text(self, text: str) -> List[float]:
        embedding_model = self.load_model()
        return await embedding_model.aembed_query(text)

    async def a_embed_texts(self, texts: List[str]) -> List[List[float]]:
        embedding_model = self.load_model()
        return await embedding_model.aembed_documents(texts)

# %%
# Synthesizer가 가진 메서드 중 'conversational'이 포함된 것 찾기
print([m for m in dir(synthesizer)])
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_a_evolve_input', '_a_generate', '_a_generate_from_context', '_a_generate_inputs', '_a_generate_schema', '_a_generate_text_to_sql_from_context', '_a_rewrite_inputs', '_evolve_input', '_generate', '_generate_inputs', '_generate_schema', '_rewrite_inputs', 'a_generate_goldens_from_contexts', 'a_generate_goldens_from_docs', 'a_generate_goldens_from_goldens', 'a_generate_goldens_from_scratch', 'async_mode', 'cost_tracking', 'evolution_config', 'filtration_config', 'generate_goldens_from_contexts', 'generate_goldens_from_docs', 'generate_goldens_from_goldens', 'generate_goldens_from_scratch', 'map_evolution_to_prompt_evolution', 'max_concurrent', 'model', 'save_as', 'set_styling_config', 'styling_config', 'synthesis_cost', 'synthetic_goldens', 'task_wrapper', 'to_pandas', 'transform_distribution', 'using_native_model']

# %%
import inspect
import deepeval.synthesizer.config as ds_config
from deepeval.synthesizer import Synthesizer

print("--- [1] EvolutionConfig 클래스 실존 확인 ---")
# deepeval.synthesizer.config 모듈 안에 EvolutionConfig가 있는지 확인합니다.
has_class = "EvolutionConfig" in dir(ds_config)
print(f"결과: {has_class} (True면 클래스가 존재하는 것입니다.)")
if has_class:
    print(f"위치: {ds_config.EvolutionConfig}")
print("\n")

print("--- [2] Synthesizer 생성자(__init__)의 인자 확인 ---")
# Synthesizer 클래스를 새로 만들 때(초기화할 때) 어떤 인자를 받는지 설계도를 봅니다.
init_sig = inspect.signature(Synthesizer.__init__)
has_param = "evolution_config" in init_sig.parameters

print(f"전체 인자 목록: {list(init_sig.parameters.keys())}")
print(f"결과: {has_param} ('evolution_config'가 목록에 있으면 100% 받는 겁니다.)")
# Out:
# --- [1] EvolutionConfig 클래스 실존 확인 ---
# 결과: True (True면 클래스가 존재하는 것입니다.)
# 위치: <class 'deepeval.synthesizer.config.EvolutionConfig'>
#
#
# --- [2] Synthesizer 생성자(__init__)의 인자 확인 ---
# 전체 인자 목록: ['self', 'model', 'async_mode', 'max_concurrent', 'filtration_config', 'evolution_config', 'styling_config', 'cost_tracking']
# 결과: True ('evolution_config'가 목록에 있으면 100% 받는 겁니다.)

# %%
from deepeval.synthesizer import Evolution

print("--- [1] Evolution 이넘(Enum) 전체 멤버 확인 ---")
# 현재 버전에서 지원하는 모든 Evolution 이름을 출력합니다.
for name in Evolution:
    print(f"- Evolution.{name.name}")

# 만약 CONVERSATIONAL이 없다면, MULTI_CONTEXT나 REASONING 등 다른 이름이 있을 겁니다.
# Out:
# --- [1] Evolution 이넘(Enum) 전체 멤버 확인 ---
# - Evolution.REASONING
# - Evolution.MULTICONTEXT
# - Evolution.CONCRETIZING
# - Evolution.CONSTRAINED
# - Evolution.COMPARATIVE
# - Evolution.HYPOTHETICAL
# - Evolution.IN_BREADTH

# %%
import inspect
from deepeval.synthesizer.config import EvolutionConfig

print("--- [2] EvolutionConfig 생성자 상세 분석 ---")
sig = inspect.signature(EvolutionConfig.__init__)
print(f"인자 목록: {sig}")

# 특정 인자의 타입 힌트를 자세히 보고 싶을 때
params = sig.parameters
if 'evolutions' in params:
    print(f"\n'evolutions' 인자의 기본값 및 타입: {params['evolutions']}")
# Out:
# --- [2] EvolutionConfig 생성자 상세 분석 ---
# 인자 목록: (self, num_evolutions: int = 1, evolutions: Dict[deepeval.synthesizer.types.Evolution, float] = <factory>) -> None
#
# 'evolutions' 인자의 기본값 및 타입: evolutions: Dict[deepeval.synthesizer.types.Evolution, float] = <factory>

# %%
from deepeval.synthesizer import Evolution

# 1. 전체 도움말 보기
help(Evolution)
# Out:
# Help on class Evolution in module deepeval.synthesizer.types:
#
# class Evolution(enum.Enum)
#  |  Evolution(*values)
#  |
#  |  Method resolution order:
#  |      Evolution
#  |      enum.Enum
#  |      builtins.object
#  |
#  |  Data and other attributes defined here:
#  |
#  |  COMPARATIVE = <Evolution.COMPARATIVE: 'Comparative'>
#  |
#  |  CONCRETIZING = <Evolution.CONCRETIZING: 'Concretizing'>
#  |
#  |  CONSTRAINED = <Evolution.CONSTRAINED: 'Constrained'>
#  |
#  |  HYPOTHETICAL = <Evolution.HYPOTHETICAL: 'Hypothetical'>
#  |
#  |  IN_BREADTH = <Evolution.IN_BREADTH: 'In-Breadth'>
#  |
#  |  MULTICONTEXT = <Evolution.MULTICONTEXT: 'Multi-context'>
#  |
#  |  REASONING = <Evolution.REASONING: 'Reasoning'>
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from enum.Enum:
#  |
#  |  name
#  |      The name of the Enum member.
#  |
#  |  value
#  |      The value of the Enum member.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods inherited from enum.EnumType:
#  |
#  |  __contains__(value)
#  |      Return True if `value` is in `cls`.
#  |
#  |      `value` is in `cls` if:
#  |      1) `value` is a member of `cls`, or
#  |      2) `value` is the value of one of the `cls`'s members.
#  |
#  |  __getitem__(name)
#  |      Return the member matching `name`.
#  |
#  |  __iter__()
#  |      Return members in definition order.
#  |
#  |  __len__()
#  |      Return the number of members (no aliases)
#  |
#  |  ----------------------------------------------------------------------
#  |  Readonly properties inherited from enum.EnumType:
#  |
#  |  __members__
#  |      Returns a mapping of member name->value.
#  |
#  |      This mapping lists all enum members, including aliases. Note that this
#  |      is a read-only view of the internal mapping.

# %%
import logging
import sys

# 모든 디버그 로그를 화면에 출력하도록 설정
logging.basicConfig(
    level=logging.DEBUG,
    format='%(asctime)s [%(levelname)s] %(message)s',
    handlers=[logging.StreamHandler(sys.stdout)]
)

# DeepEval 관련 로거만 따로 레벨 조정 (선택 사항)
logger = logging.getLogger('deepeval')
logger.setLevel(logging.DEBUG)

# %%
with open(TXT_PATH, encoding="utf-8") as f:
    full_text = f.read().strip()  # 전체 내용 로드 (약 20k자 → 문제없음)

# %%
# 1. 원문 데이터를 FAQ 한 쌍 단위로 쪼개기
# 보통 FAQ는 '\n\n'이나 'Q:'로 구분됩니다. 
raw_faq_list = full_text.split('\n\n')

# 2. DeepEval 형식에 맞게 리스트 안에 리스트로 감싸기
# DeepEval은 List[List[str]] 형식을 기대합니다.
# 각 원소(FAQ 한 세트)가 하나의 독립된 '문맥'이 됩니다.
safe_contexts = [[faq.strip()] for faq in raw_faq_list if len(faq.strip()) > 30]

print(f"총 {len(safe_contexts)}개의 개별 FAQ 문맥이 준비되었습니다.")
print("샘플 예시:", safe_contexts[0])
# Out:
# 총 126개의 개별 FAQ 문맥이 준비되었습니다.
# 샘플 예시: ['Q: 회원증을 대리발급 할 수 있나요?\nA: 회원증 대리발급은 만14세 미만 아동, 만65세 이상 어르신, 장애인, 임산부만 가능하며 아래 구비서류를 지참하여 대리인이 방문 시 대리발급이 가능합니다.']

# %%
# ────────────────────────────────────────────────
# 인스턴스 생성 (당신의 vLLM 포트 그대로)
local_llm = VLLMModel(
    model_name="/models/Exaone-3.5-32B-Instruct",
    base_url="http://localhost:8002/v1"
)

local_embedder = VLLMEmbedding(
    model_name="/embeddings/dragonkue/snowflake-arctic-embed-l-v2.0-ko",
    base_url="http://localhost:8003/v1"
)

# %%
from deepeval.synthesizer import Synthesizer, Evolution
from deepeval.synthesizer.config import EvolutionConfig

# Multi-hop 질문을 강제하기 위해 MULTICONTEXT 비중을 높입니다.
multi_hop_config = EvolutionConfig(
    evolutions={
        Evolution.MULTICONTEXT: 0.7, # 70% 확률로 서로 다른 FAQ를 엮음
        Evolution.REASONING: 0.3      # 30% 확률로 논리 추론 질문 생성
    }
)

synthesizer = Synthesizer(
    model=local_llm,
    evolution_config=multi_hop_config
)

# 생성 시작
# 이제 safe_contexts의 각 요소는 FAQ 한 개뿐이므로, 
# 모델은 정답을 찾기 위해 반드시 '다른 context'를 참조해야만 하는 상황이 됩니다.
goldens = synthesizer.generate_goldens_from_contexts(
    contexts=safe_contexts,
    include_expected_output=True,
    max_goldens_per_context=1  # 한 문맥당 1개씩만 생성 (중복 방지)
)
# Out:
# Output()
# 2026-03-04 01:14:26,088 [DEBUG] close.started
# 2026-03-04 01:14:26,147 [DEBUG] Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'idempotency_key': 'stainless-python-retry-9dc9d44f-6b8c-4462-8073-d2c383283c30', 'json_data': {'messages': [{'role': 'user', 'content': 'I want you act as a copywriter. Based on the given context, which is list of strings, please generate a list of JSON objects with a `input` key.\n        The `input` can either be a question or a statement that can be addressed by the given context.\n\n        **\n        IMPORTANT: Please make sure to only return in JSON format, with the \'data\' key as a list of JSON objects.\n        You MUST TRY to generate 1 data points, unless the `input` is getting repetitive.\n\n        Example context: ["Einstein won the Nobel Prize for his discovery of penicillin.", "Einstein won the Nobel Prize in 1968."]\n        Example max goldens per context: 2\n        Example JSON:\n        {\n            "data": [\n                {\n                    "input": "What was Einstein known for?"\n                },\n                {\n                    "input": "Einstein was a smart guy huh"\n                }\n            ]  \n        }\n\n\n        You should NOT incorporate any prior knowledge you have and take each context at face value.\n        You MUST include at least one statement as the input.\n        `input` MUST be a STRING.\n        \n        \n        You MUST TRY to generate 1 data points, unless the generated `input` is getting repetitive.\n        **\n\n        Max Goldens Per Context:\n        1\n\n        Context:\n        [\'Q: 회원증을 대리발급 할 수 있나요?\\nA: 회원증 대리발급은 만14세 미만 아동, 만65세 이상 어르신, 장애인, 임산부만 가능하며 아래 구비서류를 지참하여 대리인이 방문 시 대리발급이 가능합니다.\']\n\n        JSON:\n        '}], 'model': '/models/Exaone-3.5-32B-Instruct', 'temperature': 0}}
# 2026-03-04 01:14:26,148 [DEBUG] Sending HTTP Request: POST http://localhost:8002/v1/chat/completions
# 2026-03-04 01:14:26,148 [DEBUG] Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'idempotency_key': 'stainless-python-retry-e913dbf5-01d3-44b2-a749-944f6902ff9f', 'json_data': {'messages': [{'role': 'user', 'content': 'I want you act as a copywriter. Based on the given context, which is list of strings, please generate a list of JSON objects with a `input` key.\n        The `input` can either be a question or a statement that can be addressed by the given context.\n\n        **\n        IMPORTANT: Please make sure to only return in JSON format, with the \'data\' key as a list of JSON objects.\n        You MUST TRY to generate 1 data points, unless the `input` is getting repetitive.\n\n        Example context: ["Einstein won the Nobel Prize for his discovery of penicillin.", "Einstein won the Nobel Prize in 1968."]\n        Example max goldens per context: 2\n        Example JSON:\n        {\n            "data": [\n                {\n                    "input": "What was Einstein known for?"\n                },\n                {\n                    "input": "Einstein was a smart guy huh"\n                }\n            ]  \n        }\n\n\n        You should NOT incorporate any prior knowledge you have and take each context at face value.\n        You MUST include at least one statement as the input.\n        `input` MUST be a STRING.\n        \n        \n        You MUST TRY to generate 1 data points, unless the generated `input` is getting repetitive.\n        **\n\n        Max Goldens Per Context:\n        1\n\n        Context:\n        [\'· 대상 : 만14세 미만 아동, 만65세 이상 어르신, 장애인, 임산부\\n· 구비서류\\n\\xa0 - 공통 : ①위임자 신분증, ②피위임자(대리인) 신분증\\n\\xa0 - 장애인 : 장애인 복지카드 또는 장애인 증명서\\n\\xa0 - 임신부 : 산모수첩 / 산모 : 주민등록등본(출산 후 12개월까지)\\n· 방법 : 홈페이지 회원가입 후 위 항목의 해당하는 구비서류를 지참하여 피위임자(대리인)이 도서관 방문\']\n\n        JSON:\n        '}], 'model': '/models/Exaone-3.5-32B-Instruct', 'temperature': 0}}
# 2026-03-04 01:14:26,148 [DEBUG] Sending HTTP Request: POST http://localhost:8002/v1/chat/completions
# 2026-03-04 01:14:26,148 [DEBUG] Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'idempotency_key': 'stainless-python-retry-c5860c81-4605-4209-ba26-e807af9dad8c', 'json_data': {'messages': [{'role': 'user', 'content': 'I want you act as a copywriter. Based on the given context, which is list of strings, please generate a list of JSON objects with a `input` key.\n        The `input` can either be a question or a statement that can be addressed by the given context.\n\n        **\n        IMPORTANT: Please make sure to only return in JSON format, with the \'data\' key as a list of JSON objects.\n        You MUST TRY to generate 1 data points, unless the `input` is getting repetitive.\n\n        Example context: ["Einstein won the Nobel Prize for his discovery of penicillin.", "Einstein won the Nobel Prize in 1968."]\n        Example max goldens per context: 2\n        Example JSON:\n        {\n            "data": [\n                {\n                    "input": "What was Einstein known for?"\n                },\n                {\n                    "input": "Einstein was a smart guy huh"\n                }\n            ]  \n        }\n\n\n        You should NOT incorporate any prior knowledge you have and take each context at face value.\n        You MUST include at least one statement as the input.\n        `input` MUST be a STRING.\n        \n        \n        You MUST TRY to generate 1 data points, unless the generated `input` is getting repetitive.\n        **\n\n        Max Goldens Per Context:\n        1\n\n        Context:\n        [\'Q: 가족회원이 무엇인가요?\\nA: 가족회원이란, 고양시 도서관 정회원으로 가입 후 가족회원으로 등록 시 가족명의로 도서대출·도서예약·상호대차 동일하게 이용가능한 서비스입니다.\\n※ 가족명의 이용 시 자료실 안내데스크에 반드시 본인 회원증을 제시하여야 함(가족 회원증으로 대출 불가)\\n가족회원 등록방법\\n가족구성원 모두 정회원 가입 후 가족임을 증명할 수 있는 서류(주민등록등본 또는 가족관계증명서) 지참하여 도서관 방문\']\n\n        JSON:\n        '}], 'model': '/models/Exaone-3.5-32B-Instruct', 'temperature': 0}}
# 2026-03-04 01:14:26,149 [DEBUG] Sending HTTP Request: POST http://localhost:8002/v1/chat/completions
# 2026-03-04 01:14:26,149 [DEBUG] Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'idempotency_key': 'stainless-python-retry-cdfe85ec-b6fa-427f-9883-27f7c85358cf', 'json_data': {'messages': [{'role': 'user', 'content': 'I want you act as a copywriter. Based on the given context, which is list of strings, please generate a list of JSON objects with a `input` key.\n        The `input` can either be a question or a statement that can be addressed by the given context.\n\n        **\n        IMPORTANT: Please make sure to only return in JSON format, with the \'data\' key as a list of JSON objects.\n        You MUST TRY to generate 1 data points, unless the `input` is getting repetitive.\n\n        Example context: ["Einstein won the Nobel Prize for his discovery of penicillin.", "Einstein won the Nobel Prize in 1968."]\n        Example max goldens per context: 2\n        Example JSON:\n        {\n            "data": [\n                {\n                    "input": "What was Einstein known for?"\n                },\n                {\n                    "input": "Einstein was a smart guy huh"\n                }\n            ]  \n        }\n\n\n        You should NOT incorporate any prior knowledge you have and take each context at face value.\n        You MUST include at least one statement as the input.\n        `input` MUST be a STRING.\n        \n        \n        You MUST TRY to generate 1 data points, unless the generated `input` is getting repetitive.\n        **\n\n        Max Goldens Per Context:\n        1\n\n        Context:\n        [\'Q: 핸드폰이 없는 어린이가 홈페이지 회원가입을 하려면 어떻게 해야 하나요?\\nA: 본인명의 휴대폰 인증이 불가한 만14세 미만 어린이의\\xa0경우 아이핀(I-PIN) 본인인증 과정을 거쳐 홈페이지 가입이 가능합니다.\']\n\n        JSON:\n        '}], 'model': '/models/Exaone-3.5-32B-Instruct', 'temperature': 0}}
# 2026-03-04 01:14:26,149 [DEBUG] Sending HTTP Request: POST http://localhost:8002/v1/chat/completions
# 2026-03-04 01:14:26,149 [DEBUG] Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'idempotency_key': 'stainless-python-retry-bf122fd8-7989-4517-ad38-ed6d0e1c84fe', 'json_data': {'messages': [{'role': 'user', 'content': 'I want you act as a copywriter. Based on the given context, which is list of strings, please generate a list of JSON objects with a `input` key.\n        The `input` can either be a question or a statement that can be addressed by the given context.\n\n        **\n        IMPORTANT: Please make sure to only return in JSON format, with the \'data\' key as a list of JSON objects.\n        You MUST TRY to generate 1 data points, unless the `input` is getting repetitive.\n\n        Example context: ["Einstein won the Nobel Prize for his discovery of penicillin.", "Einstein won the Nobel Prize in 1968."]\n        Example max goldens per context: 2\n        Example JSON:\n        {\n            "data": [\n                {\n                    "input": "What was Einstein known for?"\n                },\n                {\n                    "input": "Einstein was a smart guy huh"\n                }\n            ]  \n        }\n\n\n        You should NOT incorporate any prior knowledge you have and take each context at face value.\n        You MUST include at least one statement as the input.\n        `input` MUST be a STRING.\n        \n        \n        You MUST TRY to generate 1 data points, unless the generated `input` is getting repetitive.\n        **\n\n        Max Goldens Per Context:\n        1\n\n        Context:\n        [\'홈페이지 회원가입 - 만14세 미만 회원가입(어린이회원 가입하기) - 보호자 휴대폰 인증 후 가입자(어린이)의 아이핀을 통해 홈페이지에 가입하실 수 있습니다.\']\n\n        JSON:\n        '}], 'model': '/models/Exaone-3.5-32B-Instruct', 'temperature': 0}}
# 2026-03-04 01:14:26,149 [DEBUG] Sending HTTP Request: POST http://localhost:8002/v1/chat/completions
# 2026-03-04 01:14:26,149 [DEBUG] Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'idempotency_key': 'stainless-python-retry-8b6885cc-5e15-4470-b817-ee3348d31fca', 'json_data': {'messages': [{'role': 'user', 'content': 'I want you act as a copywriter. Based on the given context, which is list of strings, please generate a list of JSON objects with a `input` key.\n        The `input` can either be a question or a statement that can be addressed by the given context.\n\n        **\n        IMPORTANT: Please make sure to only return in JSON format, with the \'data\' key as a list of JSON objects.\n        You MUST TRY to generate 1 data points, unless the `input` is getting repetitive.\n\n        Example context: ["Einstein won the Nobel Prize for his discovery of penicillin.", "Einstein won the Nobel Prize in 1968."]\n        Example max goldens per context: 2\n        Example JSON:\n        {\n            "data": [\n                {\n                    "input": "What was Einstein known for?"\n                },\n                {\n                    "input": "Einstein was a smart guy huh"\n                }\n            ]  \n        }\n\n\n        You should NOT incorporate any prior knowledge you have and take each context at face value.\n        You MUST include at least one statement as the input.\n        `input` MUST be a STRING.\n        \n        \n        You MUST TRY to generate 1 data points, unless the generated `input` is getting repetitive.\n        **\n\n        Max Goldens Per Context:\n        1\n\n        Context:\n        [\'회원가입 바로가기\\nhttps://www.goyanglib.or.kr/center/program/memberJoinType.do\']\n\n        JSON:\n        '}], 'model': '/models/Exaone-3.5-32B-Instruct', 'temperature': 0}}
# 2026-03-04 01:14:26,150 [DEBUG] Sending HTTP Request: POST http://localhost:8002/v1/chat/completions
# 2026-03-04 01:14:26,150 [DEBUG] Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'idempotency_key': 'stainless-python-retry-414fcba8-7c1f-4a67-b8b3-b0da6a442467', 'json_data': {'messages': [{'role': 'user', 'content': 'I want you act as a copywriter. Based on the given context, which is list of strings, please generate a list of JSON objects with a `input` key.\n        The `input` can either be a question or a statement that can be addressed by the given context.\n\n        **\n        IMPORTANT: Please make sure to only return in JSON format, with the \'data\' key as a list of JSON objects.\n        You MUST TRY to generate 1 data points, unless the `input` is getting repetitive.\n\n        Example context: ["Einstein won the Nobel Prize for his discovery of penicillin.", "Einstein won the Nobel Prize in 1968."]\n        Example max goldens per context: 2\n        Example JSON:\n        {\n            "data": [\n                {\n                    "input": "What was Einstein known for?"\n                },\n                {\n                    "input": "Einstein was a smart guy huh"\n                }\n            ]  \n        }\n\n\n        You should NOT incorporate any prior knowledge you have and take each context at face value.\n        You MUST include at least one statement as the input.\n        `input` MUST be a STRING.\n        \n        \n        You MUST TRY to generate 1 data points, unless the generated `input` is getting repetitive.\n        **\n\n        Max Goldens Per Context:\n        1\n\n        Context:\n        [\'Q: 회원증은 도서관마다 각각 만들어야 하나요? 또, 회원증을 분실한 경우에는 어떻게 해야 하나요?\\nA: 고양시 도서관의 회원증으로 고양시 관내 시립도서관과 공립작은도서관을 모두 이용하실 수 있습니다.\\u200b_x000D_\\n회원증을 분실하였을 경우 신분증을 지참하여 관내 어느 시립, 공립작은도서관에 가셔도 재발급 받으실 수 있습니다._x000D_\']\n\n        JSON:\n        '}], 'model': '/models/Exaone-3.5-32B-Instruct', 'temperature': 0}}
# 2026-03-04 01:14:26,150 [DEBUG] Sending HTTP Request: POST http://localhost:8002/v1/chat/completions
# 2026-03-04 01:14:26,150 [DEBUG] Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'idempotency_key': 'stainless-python-retry-4a9fd347-878d-4302-a24c-b658b9694637', 'json_data': {'messages': [{'role': 'user', 'content': 'I want you act as a copywriter. Based on the given context, which is list of strings, please generate a list of JSON objects with a `input` key.\n        The `input` can either be a question or a statement that can be addressed by the given context.\n\n        **\n        IMPORTANT: Please make sure to only return in JSON format, with the \'data\' key as a list of JSON objects.\n        You MUST TRY to generate 1 data points, unless the `input` is getting repetitive.\n\n        Example context: ["Einstein won the Nobel Prize for his discovery of penicillin.", "Einstein won the Nobel Prize in 1968."]\n        Example max goldens per context: 2\n        Example JSON:\n        {\n            "data": [\n                {\n                    "input": "What was Einstein known for?"\n                },\n                {\n                    "input": "Einstein was a smart guy huh"\n                }\n            ]  \n        }\n\n\n        You should NOT incorporate any prior knowledge you have and take each context at face value.\n        You MUST include at least one statement as the input.\n        `input` MUST be a STRING.\n        \n        \n        You MUST TRY to generate 1 data points, unless the generated `input` is getting repetitive.\n        **\n\n        Max Goldens Per Context:\n        1\n\n        Context:\n        [\'Q: 도서관 회원가입은 어떻게 하나요?\\nA: 고양시 도서관 회원은 준회원(홈페이지 가입 회원) / 정회원(관외대출회원)으로 구분되며 정회원 가입대상 및 방법은 다음과 같습니다.\']\n\n        JSON:\n        '}], 'model': '/models/Exaone-3.5-32B-Instruct', 'temperature': 0}}
# 2026-03-04 01:14:26,150 [DEBUG] Sending HTTP Request: POST http://localhost:8002/v1/chat/completions
# 2026-03-04 01:14:26,150 [DEBUG] Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'idempotency_key': 'stainless-python-retry-a7bd1cfe-1289-40e9-adc7-9f6722cd5715', 'json_data': {'messages': [{'role': 'user', 'content': 'I want you act as a copywriter. Based on the given context, which is list of strings, please generate a list of JSON objects with a `input` key.\n        The `input` can either be a question or a statement that can be addressed by the given context.\n\n        **\n        IMPORTANT: Please make sure to only return in JSON format, with the \'data\' key as a list of JSON objects.\n        You MUST TRY to generate 1 data points, unless the `input` is getting repetitive.\n\n        Example context: ["Einstein won the Nobel Prize for his discovery of penicillin.", "Einstein won the Nobel Prize in 1968."]\n        Example max goldens per context: 2\n        Example JSON:\n        {\n            "data": [\n                {\n                    "input": "What was Einstein known for?"\n                },\n                {\n                    "input": "Einstein was a smart guy huh"\n                }\n            ]  \n        }\n\n\n        You should NOT incorporate any prior knowledge you have and take each context at face value.\n        You MUST include at least one statement as the input.\n        `input` MUST be a STRING.\n        \n        \n        You MUST TRY to generate 1 data points, unless the generated `input` is getting repetitive.\n        **\n\n        Max Goldens Per Context:\n        1\n\n        Context:\n        [\'· 정회원 가입대상\\n주민등록상 경기도 거주자, 경기도소재 직장인 및 재학생\']\n\n        JSON:\n        '}], 'model': '/models/Exaone-3.5-32B-Instruct', 'temperature': 0}}
# 2026-03-04 01:14:26,150 [DEBUG] Sending HTTP Request: POST http://localhost:8002/v1/chat/completions
# 2026-03-04 01:14:26,151 [DEBUG] Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'idempotency_key': 'stainless-python-retry-2243afd1-c5cc-4180-afc8-853e803c8318', 'json_data': {'messages': [{'role': 'user', 'content': 'I want you act as a copywriter. Based on the given context, which is list of strings, please generate a list of JSON objects with a `input` key.\n        The `input` can either be a question or a statement that can be addressed by the given context.\n\n        **\n        IMPORTANT: Please make sure to only return in JSON format, with the \'data\' key as a list of JSON objects.\n        You MUST TRY to generate 1 data points, unless the `input` is getting repetitive.\n\n        Example context: ["Einstein won the Nobel Prize for his discovery of penicillin.", "Einstein won the Nobel Prize in 1968."]\n        Example max goldens per context: 2\n        Example JSON:\n        {\n            "data": [\n                {\n                    "input": "What was Einstein known for?"\n                },\n                {\n                    "input": "Einstein was a smart guy huh"\n                }\n            ]  \n        }\n\n\n        You should NOT incorporate any prior knowledge you have and take each context at face value.\n        You MUST include at least one statement as the input.\n        `input` MUST be a STRING.\n        \n        \n        You MUST TRY to generate 1 data points, unless the generated `input` is getting repetitive.\n        **\n\n        Max Goldens Per Context:\n        1\n\n        Context:\n        [\'정회원 가입방법\\n1. 온라인 발급\\n\\xa0· 대상 : 주민등록상\\xa0경기도 거주자\\n\\xa0· 홈페이지 회원가입 후 [온라인 정회원 신청] 클릭 - 인증절차 후 온라인 회원증 발급\\n2. 방문 발급\\n\\xa0· 대상 : 경기도 소재 직장인, 재학생을 포함한 고양시 도서관 정회원 신청 대상\\n\\xa0· 홈페이지 회원가입 후 구비서류를 지참하여 도서관 방문\']\n\n        JSON:\n        '}], 'model': '/models/Exaone-3.5-32B-Instruct', 'temperature': 0}}
# 2026-03-04 01:14:26,151 [DEBUG] Sending HTTP Request: POST http://localhost:8002/v1/chat/completions
# 2026-03-04 01:14:26,151 [DEBUG] Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'idempotency_key': 'stainless-python-retry-130acdf8-df96-4eb8-946c-212a1b127410', 'json_data': {'messages': [{'role': 'user', 'content': 'I want you act as a copywriter. Based on the given context, which is list of strings, please generate a list of JSON objects with a `input` key.\n        The `input` can either be a question or a statement that can be addressed by the given context.\n\n        **\n        IMPORTANT: Please make sure to only return in JSON format, with the \'data\' key as a list of JSON objects.\n        You MUST TRY to generate 1 data points, unless the `input` is getting repetitive.\n\n        Example context: ["Einstein won the Nobel Prize for his discovery of penicillin.", "Einstein won the Nobel Prize in 1968."]\n        Example max goldens per context: 2\n        Example JSON:\n        {\n            "data": [\n                {\n                    "input": "What was Einstein known for?"\n                },\n                {\n                    "input": "Einstein was a smart guy huh"\n                }\n            ]  \n        }\n\n\n        You should NOT incorporate any prior knowledge you have and take each context at face value.\n        You MUST include at least one statement as the input.\n        `input` MUST be a STRING.\n        \n        \n        You MUST TRY to generate 1 data points, unless the generated `input` is getting repetitive.\n        **\n\n        Max Goldens Per Context:\n        1\n\n        Context:\n        [\'구비서류\\n이용안내 - 회원가입 - 회원증 방문발급 - 구비서류 안내 참고\']\n\n        JSON:\n        '}], 'model': '/models/Exaone-3.5-32B-Instruct', 'temperature': 0}}
# 2026-03-04 01:14:26,151 [DEBUG] Sending HTTP Request: POST http://localhost:8002/v1/chat/completions
# 2026-03-04 01:14:26,151 [DEBUG] Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'idempotency_key': 'stainless-python-retry-48cb53f8-8d8b-41d3-a4c2-66e973ab184d', 'json_data': {'messages': [{'role': 'user', 'content': 'I want you act as a copywriter. Based on the given context, which is list of strings, please generate a list of JSON objects with a `input` key.\n        The `input` can either be a question or a statement that can be addressed by the given context.\n\n        **\n        IMPORTANT: Please make sure to only return in JSON format, with the \'data\' key as a list of JSON objects.\n        You MUST TRY to generate 1 data points, unless the `input` is getting repetitive.\n\n        Example context: ["Einstein won the Nobel Prize for his discovery of penicillin.", "Einstein won the Nobel Prize in 1968."]\n        Example max goldens per context: 2\n        Example JSON:\n        {\n            "data": [\n                {\n                    "input": "What was Einstein known for?"\n                },\n                {\n                    "input": "Einstein was a smart guy huh"\n                }\n            ]  \n        }\n\n\n        You should NOT incorporate any prior knowledge you have and take each context at face value.\n        You MUST include at least one statement as the input.\n        `input` MUST be a STRING.\n        \n        \n        You MUST TRY to generate 1 data points, unless the generated `input` is getting repetitive.\n        **\n\n        Max Goldens Per Context:\n        1\n\n        Context:\n        [\'Q: 사립 작은도서관 등록·변경·폐관 절차에 대해 궁금합니다.\\nA: 사립 작은도서관을 등록,변경,폐관 절차에 대한 자세한 내용은_x000D_\\n도서관센터 홈페이지- 작은도서관- 사립작은도서관 등록신청메뉴에서 확인 가능합니다._x000D_\\n관련 서류 작성 후 메일로 보내주시면 확인 후 연락드리겠습니다.(도서관센터 독서진흥팀)_x000D_\']\n\n        JSON:\n        '}], 'model': '/models/Exaone-3.5-32B-Instruct', 'temperature': 0}}
# 2026-03-04 01:14:26,152 [DEBUG] Sending HTTP Request: POST http://localhost:8002/v1/chat/completions
# 2026-03-04 01:14:26,152 [DEBUG] Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'idempotency_key': 'stainless-python-retry-933b26f6-c19c-44f0-b54a-91fd2f83e223', 'json_data': {'messages': [{'role': 'user', 'content': 'I want you act as a copywriter. Based on the given context, which is list of strings, please generate a list of JSON objects with a `input` key.\n        The `input` can either be a question or a statement that can be addressed by the given context.\n\n        **\n        IMPORTANT: Please make sure to only return in JSON format, with the \'data\' key as a list of JSON objects.\n        You MUST TRY to generate 1 data points, unless the `input` is getting repetitive.\n\n        Example context: ["Einstein won the Nobel Prize for his discovery of penicillin.", "Einstein won the Nobel Prize in 1968."]\n        Example max goldens per context: 2\n        Example JSON:\n        {\n            "data": [\n                {\n                    "input": "What was Einstein known for?"\n                },\n                {\n                    "input": "Einstein was a smart guy huh"\n                }\n            ]  \n        }\n\n\n        You should NOT incorporate any prior knowledge you have and take each context at face value.\n        You MUST include at least one statement as the input.\n        `input` MUST be a STRING.\n        \n        \n        You MUST TRY to generate 1 data points, unless the generated `input` is getting repetitive.\n        **\n\n        Max Goldens Per Context:\n        1\n\n        Context:\n        [\'Q: 사립 작은도서관의 등록 기준에 대해 알려주세요.\\nA: 도서관법(시행령 제3조 1항)상 건물면적은 33㎡이상(현관,휴게실,복도,화장실,식당 면적 불포함). 자료는 1,000점 이상을 갖춘 작은도서관 이면서,_x000D_\\n건축법상(시행령 제5조의 5) 제 1종 근린생활시설, 교육연구시설, 단독주택 1층, 공동주택에 위치한 작은도서관만 등록이 가능합니다._x000D_\\n_x000D_\\n자세한 내용은 고양시 도서관센터 홈페이지-작은도서관-사립작은도서관 등록신청의 [서식5 체크리스트]를 참고해 주시기 바랍니다._x000D_\\n_x000D_\\n_x000D_\']\n\n        JSON:\n        '}], 'model': '/models/Exaone-3.5-32B-Instruct', 'temperature': 0}}
# 2026-03-04 01:14:26,158 [DEBUG] Sending HTTP Request: POST http://localhost:8002/v1/chat/completions
# 2026-03-04 01:14:26,159 [DEBUG] Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'idempotency_key': 'stainless-python-retry-749e573f-22eb-46ce-be63-875e16448ec6', 'json_data': {'messages': [{'role': 'user', 'content': 'I want you act as a copywriter. Based on the given context, which is list of strings, please generate a list of JSON objects with a `input` key.\n        The `input` can either be a question or a statement that can be addressed by the given context.\n\n        **\n        IMPORTANT: Please make sure to only return in JSON format, with the \'data\' key as a list of JSON objects.\n        You MUST TRY to generate 1 data points, unless the `input` is getting repetitive.\n\n        Example context: ["Einstein won the Nobel Prize for his discovery of penicillin.", "Einstein won the Nobel Prize in 1968."]\n        Example max goldens per context: 2\n        Example JSON:\n        {\n            "data": [\n                {\n                    "input": "What was Einstein known for?"\n                },\n                {\n                    "input": "Einstein was a smart guy huh"\n                }\n            ]  \n        }\n\n\n        You should NOT incorporate any prior knowledge you have and take each context at face value.\n        You MUST include at least one statement as the input.\n        `input` MUST be a STRING.\n        \n        \n        You MUST TRY to generate 1 data points, unless the generated `input` is getting repetitive.\n        **\n\n        Max Goldens Per Context:\n        1\n\n        Context:\n        [\'Q: 사립 작은도서관은 무엇인가요 ?\\nA: 사립작은도서관은 다양한 주체가 다양한 방법으로 설립,운영하는 민간분야의 작은도서관 입니다._x000D_\\n고양시에는 현재 기준(2025. 6.) 총 87개의 사립 작은도서관이 있습니다._x000D_\']\n\n        JSON:\n        '}], 'model': '/models/Exaone-3.5-32B-Instruct', 'temperature': 0}}
# 2026-03-04 01:14:26,160 [DEBUG] Sending HTTP Request: POST http://localhost:8002/v1/chat/completions
# 2026-03-04 01:14:26,161 [DEBUG] Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'idempotency_key': 'stainless-python-retry-36a58a57-5a5c-4eb9-a139-c66f524a1c6d', 'json_data': {'messages': [{'role': 'user', 'content': 'I want you act as a copywriter. Based on the given context, which is list of strings, please generate a list of JSON objects with a `input` key.\n        The `input` can either be a question or a statement that can be addressed by the given context.\n\n        **\n        IMPORTANT: Please make sure to only return in JSON format, with the \'data\' key as a list of JSON objects.\n        You MUST TRY to generate 1 data points, unless the `input` is getting repetitive.\n\n        Example context: ["Einstein won the Nobel Prize for his discovery of penicillin.", "Einstein won the Nobel Prize in 1968."]\n        Example max goldens per context: 2\n        Example JSON:\n        {\n            "data": [\n                {\n                    "input": "What was Einstein known for?"\n                },\n                {\n                    "input": "Einstein was a smart guy huh"\n                }\n            ]  \n        }\n\n\n        You should NOT incorporate any prior knowledge you have and take each context at face value.\n        You MUST include at least one statement as the input.\n        `input` MUST be a STRING.\n        \n        \n        You MUST TRY to generate 1 data points, unless the generated `input` is getting repetitive.\n        **\n\n        Max Goldens Per Context:\n        1\n\n        Context:\n        [\'Q: 시립도서관 대출증으로 작은도서관도 이용 가능한가요?\\nA: 고양시도서관센터 회원증으로 시립도서관 및 공립작은도서관 모두 이용가능합니다.\']\n\n        JSON:\n        '}], 'model': '/models/Exaone-3.5-32B-Instruct', 'temperature': 0}}
# 2026-03-04 01:14:26,161 [DEBUG] Sending HTTP Request: POST http://localhost:8002/v1/chat/completions
# 2026-03-04 01:14:26,161 [DEBUG] Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'idempotency_key': 'stainless-python-retry-0a832418-268b-4c35-b55e-72f81bdd38f1', 'json_data': {'messages': [{'role': 'user', 'content': 'I want you act as a copywriter. Based on the given context, which is list of strings, please generate a list of JSON objects with a `input` key.\n        The `input` can either be a question or a statement that can be addressed by the given context.\n\n        **\n        IMPORTANT: Please make sure to only return in JSON format, with the \'data\' key as a list of JSON objects.\n        You MUST TRY to generate 1 data points, unless the `input` is getting repetitive.\n\n        Example context: ["Einstein won the Nobel Prize for his discovery of penicillin.", "Einstein won the Nobel Prize in 1968."]\n        Example max goldens per context: 2\n        Example JSON:\n        {\n            "data": [\n                {\n                    "input": "What was Einstein known for?"\n                },\n                {\n                    "input": "Einstein was a smart guy huh"\n                }\n            ]  \n        }\n\n\n        You should NOT incorporate any prior knowledge you have and take each context at face value.\n        You MUST include at least one statement as the input.\n        `input` MUST be a STRING.\n        \n        \n        You MUST TRY to generate 1 data points, unless the generated `input` is getting repetitive.\n        **\n\n        Max Goldens Per Context:\n        1\n\n        Context:\n        [\'Q: 작은도서관에서 빌린 책을 시립도서관에 반납 해도 될까요?\\nA: 작은도서관에서 빌린 책은 해당 작은도서관으로 반납해주세요.(상호대차, 통합반납, 지하철역반납 불가)\']\n\n        JSON:\n        '}], 'model': '/models/Exaone-3.5-32B-Instruct', 'temperature': 0}}
# 2026-03-04 01:14:26,162 [DEBUG] Sending HTTP Request: POST http://localhost:8002/v1/chat/completions
# 2026-03-04 01:14:26,162 [DEBUG] Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'idempotency_key': 'stainless-python-retry-0642fda6-145f-419e-91d8-6152badad8c6', 'json_data': {'messages': [{'role': 'user', 'content': 'I want you act as a copywriter. Based on the given context, which is list of strings, please generate a list of JSON objects with a `input` key.\n        The `input` can either be a question or a statement that can be addressed by the given context.\n\n        **\n        IMPORTANT: Please make sure to only return in JSON format, with the \'data\' key as a list of JSON objects.\n        You MUST TRY to generate 1 data points, unless the `input` is getting repetitive.\n\n        Example context: ["Einstein won the Nobel Prize for his discovery of penicillin.", "Einstein won the Nobel Prize in 1968."]\n        Example max goldens per context: 2\n        Example JSON:\n        {\n            "data": [\n                {\n                    "input": "What was Einstein known for?"\n                },\n                {\n                    "input": "Einstein was a smart guy huh"\n                }\n            ]  \n        }\n\n\n        You should NOT incorporate any prior knowledge you have and take each context at face value.\n        You MUST include at least one statement as the input.\n        `input` MUST be a STRING.\n        \n        \n        You MUST TRY to generate 1 data points, unless the generated `input` is getting repetitive.\n        **\n\n        Max Goldens Per Context:\n        1\n\n        Context:\n        [\'Q: 공립작은도서관을 알려주세요.\\nA: 관산, 내유, 대덕, 사리현, 화전, 마상공원, 모당공원 작은도서관이 있습니다.\']\n\n        JSON:\n        '}], 'model': '/models/Exaone-3.5-32B-Instruct', 'temperature': 0}}
# 2026-03-04 01:14:26,162 [DEBUG] Sending HTTP Request: POST http://localhost:8002/v1/chat/completions
# 2026-03-04 01:14:26,163 [DEBUG] Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'idempotency_key': 'stainless-python-retry-d945bbb0-5b35-4763-bada-f84002edd06e', 'json_data': {'messages': [{'role': 'user', 'content': 'I want you act as a copywriter. Based on the given context, which is list of strings, please generate a list of JSON objects with a `input` key.\n        The `input` can either be a question or a statement that can be addressed by the given context.\n\n        **\n        IMPORTANT: Please make sure to only return in JSON format, with the \'data\' key as a list of JSON objects.\n        You MUST TRY to generate 1 data points, unless the `input` is getting repetitive.\n\n        Example context: ["Einstein won the Nobel Prize for his discovery of penicillin.", "Einstein won the Nobel Prize in 1968."]\n        Example max goldens per context: 2\n        Example JSON:\n        {\n            "data": [\n                {\n                    "input": "What was Einstein known for?"\n                },\n                {\n                    "input": "Einstein was a smart guy huh"\n                }\n            ]  \n        }\n\n\n        You should NOT incorporate any prior knowledge you have and take each context at face value.\n        You MUST include at least one statement as the input.\n        `input` MUST be a STRING.\n        \n        \n        You MUST TRY to generate 1 data points, unless the generated `input` is getting repetitive.\n        **\n\n        Max Goldens Per Context:\n        1\n\n        Context:\n        [\'Q: 스마트 도서관 도서 검색이 가능한가요?\\nA: 자료검색-스마트도서관 도서검색 탭에서 가능합니다.\']\n\n        JSON:\n        '}], 'model': '/models/Exaone-3.5-32B-Instruct', 'temperature': 0}}
# 2026-03-04 01:14:26,163 [DEBUG] Sending HTTP Request: POST http://localhost:8002/v1/chat/completions
# 2026-03-04 01:14:26,163 [DEBUG] Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'idempotency_key': 'stainless-python-retry-f6aa93a7-ec7f-40df-96ae-e418bf560e9e', 'json_data': {'messages': [{'role': 'user', 'content': 'I want you act as a copywriter. Based on the given context, which is list of strings, please generate a list of JSON objects with a `input` key.\n        The `input` can either be a question or a statement that can be addressed by the given context.\n\n        **\n        IMPORTANT: Please make sure to only return in JSON format, with the \'data\' key as a list of JSON objects.\n        You MUST TRY to generate 1 data points, unless the `input` is getting repetitive.\n\n        Example context: ["Einstein won the Nobel Prize for his discovery of penicillin.", "Einstein won the Nobel Prize in 1968."]\n        Example max goldens per context: 2\n        Example JSON:\n        {\n            "data": [\n                {\n                    "input": "What was Einstein known for?"\n                },\n                {\n                    "input": "Einstein was a smart guy huh"\n                }\n            ]  \n        }\n\n\n        You should NOT incorporate any prior knowledge you have and take each context at face value.\n        You MUST include at least one statement as the input.\n        `input` MUST be a STRING.\n        \n        \n        You MUST TRY to generate 1 data points, unless the generated `input` is getting repetitive.\n        **\n\n        Max Goldens Per Context:\n        1\n\n        Context:\n        [\'Q: 스마트 도서관 책은 어디에 반납해야하나요?\\nA: 스마트도서관 도서 반납은 반드시 대출한 기기에 해야 합니다. _x000D_\\n(상호대차, 책누리 반납 불가)\']\n\n        JSON:\n        '}], 'model': '/models/Exaone-3.5-32B-Instruct', 'temperature': 0}}
# 2026-03-04 01:14:26,164 [DEBUG] Sending HTTP Request: POST http://localhost:8002/v1/chat/completions
# 2026-03-04 01:14:26,164 [DEBUG] Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'idempotency_key': 'stainless-python-retry-e718c572-18c3-4922-a864-e1e1e0f2cfec', 'json_data': {'messages': [{'role': 'user', 'content': 'I want you act as a copywriter. Based on the given context, which is list of strings, please generate a list of JSON objects with a `input` key.\n        The `input` can either be a question or a statement that can be addressed by the given context.\n\n        **\n        IMPORTANT: Please make sure to only return in JSON format, with the \'data\' key as a list of JSON objects.\n        You MUST TRY to generate 1 data points, unless the `input` is getting repetitive.\n\n        Example context: ["Einstein won the Nobel Prize for his discovery of penicillin.", "Einstein won the Nobel Prize in 1968."]\n        Example max goldens per context: 2\n        Example JSON:\n        {\n            "data": [\n                {\n                    "input": "What was Einstein known for?"\n                },\n                {\n                    "input": "Einstein was a smart guy huh"\n                }\n            ]  \n        }\n\n\n        You should NOT incorporate any prior knowledge you have and take each context at face value.\n        You MUST include at least one statement as the input.\n        `input` MUST be a STRING.\n        \n        \n        You MUST TRY to generate 1 data points, unless the generated `input` is getting repetitive.\n        **\n\n        Max Goldens Per Context:\n        1\n\n        Context:\n        [\'Q: 스마트 도서관은 어떻게 이용하나요?\\nA: 고양시도서관센터 회원증 소지자는 누구나 이용 가능 합니다. _x000D_\\n(회원증 발급은 도서관센터 홈페이지 회원가입 후 가까운 시립도서관 방문하여 회원증 발급(신분증 지참)_x000D_\\n_x000D_\\n1인 2권까지 가능하며 일반도서 대출과 동일하게 대출기간은 14일 1회 반납연기가 가능합니다._x000D_\\n(지축역, 삼송역, 원당역, 화정역, 고양시청 스마트도서관은 화정도서관 대출권수에 포함, 마두역, 백마역 스마트도서관은 아람누리도서관 대출권수에 포함, 주엽역, 대화역, 일산역 스마트도서관은 대화도서관 대출권수에 포함)\']\n\n        JSON:\n        '}], 'model': '/models/Exaone-3.5-32B-Instruct', 'temperature': 0}}
# 2026-03-04 01:14:26,164 [DEBUG] Sending HTTP Request: POST http://localhost:8002/v1/chat/completions
# 2026-03-04 01:14:26,164 [DEBUG] Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'idempotency_key': 'stainless-python-retry-c9cd6e77-756b-48a6-8bf6-4400605fe56d', 'json_data': {'messages': [{'role': 'user', 'content': 'I want you act as a copywriter. Based on the given context, which is list of strings, please generate a list of JSON objects with a `input` key.\n        The `input` can either be a question or a statement that can be addressed by the given context.\n\n        **\n        IMPORTANT: Please make sure to only return in JSON format, with the \'data\' key as a list of JSON objects.\n        You MUST TRY to generate 1 data points, unless the `input` is getting repetitive.\n\n        Example context: ["Einstein won the Nobel Prize for his discovery of penicillin.", "Einstein won the Nobel Prize in 1968."]\n        Example max goldens per context: 2\n        Example JSON:\n        {\n            "data": [\n                {\n                    "input": "What was Einstein known for?"\n                },\n                {\n                    "input": "Einstein was a smart guy huh"\n                }\n            ]  \n        }\n\n\n        You should NOT incorporate any prior knowledge you have and take each context at face value.\n        You MUST include at least one statement as the input.\n        `input` MUST be a STRING.\n        \n        \n        You MUST TRY to generate 1 data points, unless the generated `input` is getting repetitive.\n        **\n\n        Max Goldens Per Context:\n        1\n\n        Context:\n        [\'Q: 스마트도서관은 어디에 있나요?\\nA: 지축역, 삼송역, 원당역, 화정역, 마두역, 주엽역, 대화역, 일산역, 고양시청, 백마역 총 10개소 입니다.\']\n\n        JSON:\n        '}], 'model': '/models/Exaone-3.5-32B-Instruct', 'temperature': 0}}
# 2026-03-04 01:14:26,165 [DEBUG] Sending HTTP Request: POST http://localhost:8002/v1/chat/completions
# 2026-03-04 01:14:26,165 [DEBUG] Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'idempotency_key': 'stainless-python-retry-df77eb8a-e1dd-43fd-90e6-6c4935ae5d3e', 'json_data': {'messages': [{'role': 'user', 'content': 'I want you act as a copywriter. Based on the given context, which is list of strings, please generate a list of JSON objects with a `input` key.\n        The `input` can either be a question or a statement that can be addressed by the given context.\n\n        **\n        IMPORTANT: Please make sure to only return in JSON format, with the \'data\' key as a list of JSON objects.\n        You MUST TRY to generate 1 data points, unless the `input` is getting repetitive.\n\n        Example context: ["Einstein won the Nobel Prize for his discovery of penicillin.", "Einstein won the Nobel Prize in 1968."]\n        Example max goldens per context: 2\n        Example JSON:\n        {\n            "data": [\n                {\n                    "input": "What was Einstein known for?"\n                },\n                {\n                    "input": "Einstein was a smart guy huh"\n                }\n            ]  \n        }\n\n\n        You should NOT incorporate any prior knowledge you have and take each context at face value.\n        You MUST include at least one statement as the input.\n        `input` MUST be a STRING.\n        \n        \n        You MUST TRY to generate 1 data points, unless the generated `input` is getting repetitive.\n        **\n\n        Max Goldens Per Context:\n        1\n\n        Context:\n        [\'Q: 스마트도서관이란 무엇인가요?\\nA: 고양시도서관 회원이면 누구나 365일 이용가능한 무인도서 대출반납기입니다.(400~600여권 비치)\']\n\n        JSON:\n        '}], 'model': '/models/Exaone-3.5-32B-Instruct', 'temperature': 0}}
# 2026-03-04 01:14:26,165 [DEBUG] Sending HTTP Request: POST http://localhost:8002/v1/chat/completions
# 2026-03-04 01:14:26,166 [DEBUG] Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'idempotency_key': 'stainless-python-retry-c274460c-25b3-4f44-8afe-21d4121cc81f', 'json_data': {'messages': [{'role': 'user', 'content': 'I want you act as a copywriter. Based on the given context, which is list of strings, please generate a list of JSON objects with a `input` key.\n        The `input` can either be a question or a statement that can be addressed by the given context.\n\n        **\n        IMPORTANT: Please make sure to only return in JSON format, with the \'data\' key as a list of JSON objects.\n        You MUST TRY to generate 1 data points, unless the `input` is getting repetitive.\n\n        Example context: ["Einstein won the Nobel Prize for his discovery of penicillin.", "Einstein won the Nobel Prize in 1968."]\n        Example max goldens per context: 2\n        Example JSON:\n        {\n            "data": [\n                {\n                    "input": "What was Einstein known for?"\n                },\n                {\n                    "input": "Einstein was a smart guy huh"\n                }\n            ]  \n        }\n\n\n        You should NOT incorporate any prior knowledge you have and take each context at face value.\n        You MUST include at least one statement as the input.\n        `input` MUST be a STRING.\n        \n        \n        You MUST TRY to generate 1 data points, unless the generated `input` is getting repetitive.\n        **\n\n        Max Goldens Per Context:\n        1\n\n        Context:\n        [\'Q: 책바다, 책나래 서비스는 무엇인가요?\\nA: 책바다 서비스란?_x000D_\\n고양시 도서관에 구비되어 있지 않은 자료를 전국 책바다 서비스에 가입되어 있는 도서관 소장자료 중에서 대출하여 드리는 서비스_x000D_(공공도서관, 대학도서관 등)_x000D_\\n_x000D_\\n1. 국립중앙도서관 책바다 가입 후 이용가능_x000D_\\n(홈페이지주소 : https://books.nl.go.kr)_x000D_\\n2. 비용있음_x000D_\\n_x000D_\\n책나래 서비스란?_x000D_\\n도서관방문이 어려운 장애인과 거동불편자 등이 필요로 하는 도서관 자료를 우체국택배를 이용하여 집까지 무료로 배달해주는 서비스_x000D_\\n대상 :\\u3000보건복지부 등록 장애인, 국가보훈처 등록 국가유공상이자, 거동불편자（국가건강보험공단 인정 장기요양 대상자)_x000D_\\n_x000D_\\n1. 고양시 도서관 회원가입(도서관 대출증 발급) _x000D_\\n※ 증명서류 제출(직접방문, 대리방문, 팩스, 이메일 가능) _x000D_\\n보건복지부 등록 장애인의 경우 책나래 홈페이지 가입 시 [장애인정보 사실 여부] 조회 및 인증으로 증명서류 확인절차 생략_x000D_\\n국가보훈처 등록 국가유공상이자, 거동불편자의 경우 증명서류를 도서관에 제시(최초 1회)_x000D_\\n2. 책나래 홈페이지(http://cn.nl.go.kr) 회원가입_x000D_\\n3. 책나래 홈페이지에서 나의 도서관(고양시 소속도서관) 등록 및 회원 승인_x000D_\\n4. 책나래 홈페이지에서 자료검색 및 신청_x000D_\\n5. 신청도서관에서 신청 확인 후 도서를 우체국 택배 발송_x000D_\\n6. 반납방법 : 책나래 홈페이지에서 반납 신청_x000D_\\n7. 비용없음\']\n\n        JSON:\n        '}], 'model': '/models/Exaone-3.5-32B-Instruct', 'temperature': 0}}
# 2026-03-04 01:14:26,166 [DEBUG] Sending HTTP Request: POST http://localhost:8002/v1/chat/completions
# 2026-03-04 01:14:26,166 [DEBUG] Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'idempotency_key': 'stainless-python-retry-b7d5c787-1057-4cc6-8ea5-a7b385f3c256', 'json_data': {'messages': [{'role': 'user', 'content': 'I want you act as a copywriter. Based on the given context, which is list of strings, please generate a list of JSON objects with a `input` key.\n        The `input` can either be a question or a statement that can be addressed by the given context.\n\n        **\n        IMPORTANT: Please make sure to only return in JSON format, with the \'data\' key as a list of JSON objects.\n        You MUST TRY to generate 1 data points, unless the `input` is getting repetitive.\n\n        Example context: ["Einstein won the Nobel Prize for his discovery of penicillin.", "Einstein won the Nobel Prize in 1968."]\n        Example max goldens per context: 2\n        Example JSON:\n        {\n            "data": [\n                {\n                    "input": "What was Einstein known for?"\n                },\n                {\n                    "input": "Einstein was a smart guy huh"\n                }\n            ]  \n        }\n\n\n        You should NOT incorporate any prior knowledge you have and take each context at face value.\n        You MUST include at least one statement as the input.\n        `input` MUST be a STRING.\n        \n        \n        You MUST TRY to generate 1 data points, unless the generated `input` is getting repetitive.\n        **\n\n        Max Goldens Per Context:\n        1\n\n        Context:\n        [\'Q: 내 생애 첫도서관, 두루두루 서비스는 무엇인가요?\\nA: 내 생애 첫 도서관이란?_x000D_\\n도서관 방문이 어려운 임산부와 영유아에게 이용자가 거주하는 관내 공공도서관의 소장도서를 택배를 통해 집으로 보내드리는 서비스입니다._x000D_\\n- 서비스대상 : 임신부(개월수 제한 없음), 12개월 이하 아이를 둔 부모 중 1인_x000D_\\n- 이용기간 : 임신(개월수 제한 없음)이후 자녀 생후 12개월까지_x000D_\\n- 서비스내용 : 월 2회, 회당 5권, 제공될 날로부터 14일간 (1회 7일 연장가능)_x000D_\\n- 신 청 방 법 _x000D_\\n  경기도사이버도서관(www.library.kr)에서『내 생애 첫도서관』회원신청_x000D_\\n  가까운 고양시도서관 방문 회원가입_x000D_\\n- 확인서류 : 산모수첩 사본 혹은 주민등록등본 1부, 회원가입신청서 1부_x000D_\\n_x000D_\\n두루두루 서비스란?_x000D_\\n도서관 방문이 어려운 장애인들에게 이용자가 거주하는 관내 공공도서관의 소장도서를 택배를 통해 집으로 보내드리는 서비스입니다.\\u200b_x000D_\\n- 서비스대상 : 대출회원 중 등록 장애인 회원_x000D_\\n- 서비스내용 : 월 5회, 회당 5권, 제공될 날로부터 14일간 (1회 7일 연장가능)_x000D_\\n- 신 청 방 법 _x000D_\\n  경기도사이버도서관(www.library.kr)에서『두루두루』회원신청_x000D_\\n  가까운 고양시도서관 방문 회원가입_x000D_\\n- 확인서류 : 장애인복지카드 사본, 회원가입신청서 각 1부\']\n\n        JSON:\n        '}], 'model': '/models/Exaone-3.5-32B-Instruct', 'temperature': 0}}
# 2026-03-04 01:14:26,167 [DEBUG] Sending HTTP Request: POST http://localhost:8002/v1/chat/completions
# ...
# 2026-03-04 01:14:56,061 [DEBUG] receive_response_body.complete
# 2026-03-04 01:14:56,061 [DEBUG] response_closed.started
# 2026-03-04 01:14:56,062 [DEBUG] response_closed.complete
# 2026-03-04 01:14:56,063 [DEBUG] HTTP Response: POST http://localhost:8002/v1/chat/completions "200 OK" Headers({'date': 'Tue, 03 Mar 2026 16:14:41 GMT', 'server': 'uvicorn', 'content-length': '736', 'content-type': 'application/json'})
# 2026-03-04 01:14:56,063 [DEBUG] request_id: None
# 2026-03-04 01:14:56,064 [DEBUG] response_closed.complete
# 2026-03-04 01:14:56,065 [DEBUG] HTTP Response: POST http://localhost:8002/v1/chat/completions "200 OK" Headers({'date': 'Tue, 03 Mar 2026 16:14:41 GMT', 'server': 'uvicorn', 'content-length': '743', 'content-type': 'application/json'})
# 2026-03-04 01:14:56,065 [DEBUG] request_id: None
# 2026-03-04 01:14:56,349 [DEBUG] receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'date', b'Tue, 03 Mar 2026 16:14:41 GMT'), (b'server', b'uvicorn'), (b'content-length', b'733'), (b'content-type', b'application/json')])
# 2026-03-04 01:14:56,351 [INFO] HTTP Request: POST http://localhost:8002/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-03-04 01:14:56,351 [DEBUG] receive_response_body.started request=<Request [b'POST']>
# 2026-03-04 01:14:56,352 [DEBUG] receive_response_body.complete
# 2026-03-04 01:14:56,352 [DEBUG] response_closed.started
# 2026-03-04 01:14:56,353 [DEBUG] receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'date', b'Tue, 03 Mar 2026 16:14:40 GMT'), (b'server', b'uvicorn'), (b'content-length', b'743'), (b'content-type', b'application/json')])
# 2026-03-04 01:14:56,353 [INFO] HTTP Request: POST http://localhost:8002/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-03-04 01:14:56,353 [DEBUG] receive_response_body.started request=<Request [b'POST']>
# 2026-03-04 01:14:56,354 [DEBUG] receive_response_body.complete
# 2026-03-04 01:14:56,354 [DEBUG] response_closed.started
# 2026-03-04 01:14:56,354 [DEBUG] response_closed.complete
# 2026-03-04 01:14:56,355 [DEBUG] HTTP Response: POST http://localhost:8002/v1/chat/completions "200 OK" Headers({'date': 'Tue, 03 Mar 2026 16:14:41 GMT', 'server': 'uvicorn', 'content-length': '733', 'content-type': 'application/json'})
# 2026-03-04 01:14:56,355 [DEBUG] request_id: None
# 2026-03-04 01:14:56,356 [DEBUG] response_closed.complete
# 2026-03-04 01:14:56,356 [DEBUG] HTTP Response: POST http://localhost:8002/v1/chat/completions "200 OK" Headers({'date': 'Tue, 03 Mar 2026 16:14:40 GMT', 'server': 'uvicorn', 'content-length': '743', 'content-type': 'application/json'})
# 2026-03-04 01:14:56,356 [DEBUG] request_id: None
# 2026-03-04 01:14:56,641 [DEBUG] receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'date', b'Tue, 03 Mar 2026 16:14:40 GMT'), (b'server', b'uvicorn'), (b'content-length', b'765'), (b'content-type', b'application/json')])
# 2026-03-04 01:14:56,642 [INFO] HTTP Request: POST http://localhost:8002/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-03-04 01:14:56,643 [DEBUG] receive_response_body.started request=<Request [b'POST']>
# 2026-03-04 01:14:56,643 [DEBUG] receive_response_body.complete
# 2026-03-04 01:14:56,644 [DEBUG] response_closed.started
# 2026-03-04 01:14:56,645 [DEBUG] response_closed.complete
# 2026-03-04 01:14:56,645 [DEBUG] HTTP Response: POST http://localhost:8002/v1/chat/completions "200 OK" Headers({'date': 'Tue, 03 Mar 2026 16:14:40 GMT', 'server': 'uvicorn', 'content-length': '765', 'content-type': 'application/json'})
# 2026-03-04 01:14:56,646 [DEBUG] request_id: None
# 2026-03-04 01:14:56,932 [DEBUG] receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'date', b'Tue, 03 Mar 2026 16:14:40 GMT'), (b'server', b'uvicorn'), (b'content-length', b'769'), (b'content-type', b'application/json')])
# 2026-03-04 01:14:56,933 [INFO] HTTP Request: POST http://localhost:8002/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-03-04 01:14:56,933 [DEBUG] receive_response_body.started request=<Request [b'POST']>
# 2026-03-04 01:14:56,934 [DEBUG] receive_response_body.complete
# 2026-03-04 01:14:56,934 [DEBUG] response_closed.started
# 2026-03-04 01:14:56,935 [DEBUG] receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'date', b'Tue, 03 Mar 2026 16:14:40 GMT'), (b'server', b'uvicorn'), (b'content-length', b'769'), (b'content-type', b'application/json')])
# 2026-03-04 01:14:56,935 [INFO] HTTP Request: POST http://localhost:8002/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-03-04 01:14:56,936 [DEBUG] receive_response_body.started request=<Request [b'POST']>
# 2026-03-04 01:14:56,936 [DEBUG] receive_response_body.complete
# 2026-03-04 01:14:56,937 [DEBUG] response_closed.started
# 2026-03-04 01:14:56,937 [DEBUG] receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'date', b'Tue, 03 Mar 2026 16:14:41 GMT'), (b'server', b'uvicorn'), (b'content-length', b'766'), (b'content-type', b'application/json')])
# 2026-03-04 01:14:56,938 [INFO] HTTP Request: POST http://localhost:8002/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-03-04 01:14:56,938 [DEBUG] receive_response_body.started request=<Request [b'POST']>
# 2026-03-04 01:14:56,938 [DEBUG] receive_response_body.complete
# 2026-03-04 01:14:56,939 [DEBUG] response_closed.started
# 2026-03-04 01:14:56,939 [DEBUG] response_closed.complete
# 2026-03-04 01:14:56,939 [DEBUG] HTTP Response: POST http://localhost:8002/v1/chat/completions "200 OK" Headers({'date': 'Tue, 03 Mar 2026 16:14:40 GMT', 'server': 'uvicorn', 'content-length': '769', 'content-type': 'application/json'})
# 2026-03-04 01:14:56,940 [DEBUG] request_id: None
# 2026-03-04 01:14:56,940 [DEBUG] response_closed.complete
# 2026-03-04 01:14:56,941 [DEBUG] HTTP Response: POST http://localhost:8002/v1/chat/completions "200 OK" Headers({'date': 'Tue, 03 Mar 2026 16:14:40 GMT', 'server': 'uvicorn', 'content-length': '769', 'content-type': 'application/json'})
# 2026-03-04 01:14:56,941 [DEBUG] request_id: None
# 2026-03-04 01:14:56,941 [DEBUG] response_closed.complete
# 2026-03-04 01:14:56,941 [DEBUG] HTTP Response: POST http://localhost:8002/v1/chat/completions "200 OK" Headers({'date': 'Tue, 03 Mar 2026 16:14:41 GMT', 'server': 'uvicorn', 'content-length': '766', 'content-type': 'application/json'})
# 2026-03-04 01:14:56,942 [DEBUG] request_id: None
# 2026-03-04 01:14:57,227 [DEBUG] receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'date', b'Tue, 03 Mar 2026 16:14:40 GMT'), (b'server', b'uvicorn'), (b'content-length', b'765'), (b'content-type', b'application/json')])
# 2026-03-04 01:14:57,228 [INFO] HTTP Request: POST http://localhost:8002/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-03-04 01:14:57,229 [DEBUG] receive_response_body.started request=<Request [b'POST']>
# 2026-03-04 01:14:57,230 [DEBUG] receive_response_body.complete
# 2026-03-04 01:14:57,230 [DEBUG] response_closed.started
# 2026-03-04 01:14:57,231 [DEBUG] receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'date', b'Tue, 03 Mar 2026 16:14:41 GMT'), (b'server', b'uvicorn'), (b'content-length', b'752'), (b'content-type', b'application/json')])
# 2026-03-04 01:14:57,232 [INFO] HTTP Request: POST http://localhost:8002/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-03-04 01:14:57,233 [DEBUG] receive_response_body.started request=<Request [b'POST']>
# 2026-03-04 01:14:57,233 [DEBUG] receive_response_body.complete
# 2026-03-04 01:14:57,234 [DEBUG] response_closed.started
# 2026-03-04 01:14:57,234 [DEBUG] response_closed.complete
# 2026-03-04 01:14:57,235 [DEBUG] HTTP Response: POST http://localhost:8002/v1/chat/completions "200 OK" Headers({'date': 'Tue, 03 Mar 2026 16:14:40 GMT', 'server': 'uvicorn', 'content-length': '765', 'content-type': 'application/json'})
# 2026-03-04 01:14:57,235 [DEBUG] request_id: None
# 2026-03-04 01:14:57,236 [DEBUG] response_closed.complete
# 2026-03-04 01:14:57,236 [DEBUG] HTTP Response: POST http://localhost:8002/v1/chat/completions "200 OK" Headers({'date': 'Tue, 03 Mar 2026 16:14:41 GMT', 'server': 'uvicorn', 'content-length': '752', 'content-type': 'application/json'})
# 2026-03-04 01:14:57,237 [DEBUG] request_id: None
# 2026-03-04 01:14:57,518 [DEBUG] receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'date', b'Tue, 03 Mar 2026 16:14:41 GMT'), (b'server', b'uvicorn'), (b'content-length', b'776'), (b'content-type', b'application/json')])
# 2026-03-04 01:14:57,520 [INFO] HTTP Request: POST http://localhost:8002/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-03-04 01:14:57,520 [DEBUG] receive_response_body.started request=<Request [b'POST']>
# 2026-03-04 01:14:57,521 [DEBUG] receive_response_body.complete
# 2026-03-04 01:14:57,521 [DEBUG] response_closed.started
# 2026-03-04 01:14:57,522 [DEBUG] receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'date', b'Tue, 03 Mar 2026 16:14:41 GMT'), (b'server', b'uvicorn'), (b'content-length', b'756'), (b'content-type', b'application/json')])
# 2026-03-04 01:14:57,522 [INFO] HTTP Request: POST http://localhost:8002/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-03-04 01:14:57,522 [DEBUG] receive_response_body.started request=<Request [b'POST']>
# 2026-03-04 01:14:57,523 [DEBUG] receive_response_body.complete
# 2026-03-04 01:14:57,523 [DEBUG] response_closed.started
# 2026-03-04 01:14:57,524 [DEBUG] receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'date', b'Tue, 03 Mar 2026 16:14:40 GMT'), (b'server', b'uvicorn'), (b'content-length', b'770'), (b'content-type', b'application/json')])
# 2026-03-04 01:14:57,524 [INFO] HTTP Request: POST http://localhost:8002/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-03-04 01:14:57,525 [DEBUG] receive_response_body.started request=<Request [b'POST']>
# 2026-03-04 01:14:57,525 [DEBUG] receive_response_body.complete
# 2026-03-04 01:14:57,525 [DEBUG] response_closed.started
# 2026-03-04 01:14:57,526 [DEBUG] receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'date', b'Tue, 03 Mar 2026 16:14:41 GMT'), (b'server', b'uvicorn'), (b'content-length', b'769'), (b'content-type', b'application/json')])
# 2026-03-04 01:14:57,526 [INFO] HTTP Request: POST http://localhost:8002/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-03-04 01:14:57,526 [DEBUG] receive_response_body.started request=<Request [b'POST']>
# 2026-03-04 01:14:57,527 [DEBUG] receive_response_body.complete
# 2026-03-04 01:14:57,527 [DEBUG] response_closed.started
# 2026-03-04 01:14:57,527 [DEBUG] response_closed.complete
# 2026-03-04 01:14:57,528 [DEBUG] HTTP Response: POST http://localhost:8002/v1/chat/completions "200 OK" Headers({'date': 'Tue, 03 Mar 2026 16:14:41 GMT', 'server': 'uvicorn', 'content-length': '776', 'content-type': 'application/json'})
# 2026-03-04 01:14:57,529 [DEBUG] request_id: None
# 2026-03-04 01:14:57,529 [DEBUG] response_closed.complete
# 2026-03-04 01:14:57,530 [DEBUG] HTTP Response: POST http://localhost:8002/v1/chat/completions "200 OK" Headers({'date': 'Tue, 03 Mar 2026 16:14:41 GMT', 'server': 'uvicorn', 'content-length': '756', 'content-type': 'application/json'})
# 2026-03-04 01:14:57,530 [DEBUG] request_id: None
# 2026-03-04 01:14:57,531 [DEBUG] response_closed.complete
# 2026-03-04 01:14:57,532 [DEBUG] HTTP Response: POST http://localhost:8002/v1/chat/completions "200 OK" Headers({'date': 'Tue, 03 Mar 2026 16:14:40 GMT', 'server': 'uvicorn', 'content-length': '770', 'content-type': 'application/json'})
# 2026-03-04 01:14:57,532 [DEBUG] request_id: None
# 2026-03-04 01:14:57,533 [DEBUG] response_closed.complete
# 2026-03-04 01:14:57,533 [DEBUG] HTTP Response: POST http://localhost:8002/v1/chat/completions "200 OK" Headers({'date': 'Tue, 03 Mar 2026 16:14:41 GMT', 'server': 'uvicorn', 'content-length': '769', 'content-type': 'application/json'})
# 2026-03-04 01:14:57,534 [DEBUG] request_id: None
# 2026-03-04 01:14:59,236 [DEBUG] receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'date', b'Tue, 03 Mar 2026 16:14:41 GMT'), (b'server', b'uvicorn'), (b'content-length', b'790'), (b'content-type', b'application/json')])
# 2026-03-04 01:14:59,237 [INFO] HTTP Request: POST http://localhost:8002/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-03-04 01:14:59,238 [DEBUG] receive_response_body.started request=<Request [b'POST']>
# 2026-03-04 01:14:59,238 [DEBUG] receive_response_body.complete
# 2026-03-04 01:14:59,239 [DEBUG] response_closed.started
# 2026-03-04 01:14:59,240 [DEBUG] response_closed.complete
# 2026-03-04 01:14:59,240 [DEBUG] close.started
# 2026-03-04 01:14:59,241 [DEBUG] close.complete
# 2026-03-04 01:14:59,241 [DEBUG] HTTP Response: POST http://localhost:8002/v1/chat/completions "200 OK" Headers({'date': 'Tue, 03 Mar 2026 16:14:41 GMT', 'server': 'uvicorn', 'content-length': '790', 'content-type': 'application/json'})
# 2026-03-04 01:14:59,241 [DEBUG] request_id: None
# 2026-03-04 01:15:32,771 [DEBUG] receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'date', b'Tue, 03 Mar 2026 16:14:26 GMT'), (b'server', b'uvicorn'), (b'content-length', b'1521'), (b'content-type', b'application/json')])
# 2026-03-04 01:15:32,772 [INFO] HTTP Request: POST http://localhost:8002/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-03-04 01:15:32,773 [DEBUG] receive_response_body.started request=<Request [b'POST']>
# 2026-03-04 01:15:32,774 [DEBUG] receive_response_body.complete
# 2026-03-04 01:15:32,774 [DEBUG] response_closed.started
# 2026-03-04 01:15:32,775 [DEBUG] response_closed.complete
# 2026-03-04 01:15:32,776 [DEBUG] close.started
# 2026-03-04 01:15:32,776 [DEBUG] close.complete
# 2026-03-04 01:15:32,777 [DEBUG] close.started
# 2026-03-04 01:15:32,777 [DEBUG] close.complete
# 2026-03-04 01:15:32,777 [DEBUG] close.started
# 2026-03-04 01:15:32,777 [DEBUG] close.complete
# 2026-03-04 01:15:32,778 [DEBUG] close.started
# 2026-03-04 01:15:32,778 [DEBUG] close.complete
# 2026-03-04 01:15:32,778 [DEBUG] close.started
# 2026-03-04 01:15:32,779 [DEBUG] close.complete
# 2026-03-04 01:15:32,779 [DEBUG] close.started
# 2026-03-04 01:15:32,779 [DEBUG] close.complete
# 2026-03-04 01:15:32,780 [DEBUG] close.started
# 2026-03-04 01:15:32,780 [DEBUG] close.complete
# 2026-03-04 01:15:32,780 [DEBUG] close.started
# 2026-03-04 01:15:32,781 [DEBUG] close.complete
# 2026-03-04 01:15:32,781 [DEBUG] close.started
# 2026-03-04 01:15:32,781 [DEBUG] close.complete
# 2026-03-04 01:15:32,781 [DEBUG] close.started
# 2026-03-04 01:15:32,782 [DEBUG] close.complete
# 2026-03-04 01:15:32,782 [DEBUG] close.started
# 2026-03-04 01:15:32,782 [DEBUG] close.complete
# 2026-03-04 01:15:32,783 [DEBUG] close.started
# 2026-03-04 01:15:32,783 [DEBUG] close.complete
# 2026-03-04 01:15:32,783 [DEBUG] close.started
# 2026-03-04 01:15:32,783 [DEBUG] close.complete
# 2026-03-04 01:15:32,784 [DEBUG] close.started
# 2026-03-04 01:15:32,784 [DEBUG] close.complete
# 2026-03-04 01:15:32,784 [DEBUG] close.started
# 2026-03-04 01:15:32,785 [DEBUG] close.complete
# 2026-03-04 01:15:32,785 [DEBUG] close.started
# 2026-03-04 01:15:32,785 [DEBUG] close.complete
# 2026-03-04 01:15:32,785 [DEBUG] close.started
# 2026-03-04 01:15:32,786 [DEBUG] close.complete
# 2026-03-04 01:15:32,786 [DEBUG] close.started
# 2026-03-04 01:15:32,786 [DEBUG] close.complete
# 2026-03-04 01:15:32,786 [DEBUG] close.started
# 2026-03-04 01:15:32,787 [DEBUG] close.complete
# 2026-03-04 01:15:32,787 [DEBUG] close.started
# 2026-03-04 01:15:32,787 [DEBUG] close.complete
# 2026-03-04 01:15:32,787 [DEBUG] close.started
# 2026-03-04 01:15:32,788 [DEBUG] close.complete
# 2026-03-04 01:15:32,788 [DEBUG] close.started
# 2026-03-04 01:15:32,788 [DEBUG] close.complete
# 2026-03-04 01:15:32,789 [DEBUG] close.started
# 2026-03-04 01:15:32,789 [DEBUG] close.complete
# 2026-03-04 01:15:32,789 [DEBUG] close.started
# 2026-03-04 01:15:32,789 [DEBUG] close.complete
# 2026-03-04 01:15:32,790 [DEBUG] close.started
# 2026-03-04 01:15:32,790 [DEBUG] close.complete
# 2026-03-04 01:15:32,790 [DEBUG] HTTP Response: POST http://localhost:8002/v1/chat/completions "200 OK" Headers({'date': 'Tue, 03 Mar 2026 16:14:26 GMT', 'server': 'uvicorn', 'content-length': '1521', 'content-type': 'application/json'})
# 2026-03-04 01:15:32,791 [DEBUG] request_id: None

# %%
# 생성된 golden 리스트 확인
print("생성된 golden 개수:", len(synthesizer.synthetic_goldens))

# 첫 번째 golden 내용 전체 보기
if synthesizer.synthetic_goldens:
    first_golden = synthesizer.synthetic_goldens[0]
    print("\n=== 첫 번째 Golden 상세 ===")
    print("Input (질문):", first_golden.input)
    print("Expected Output (예상 답변):", first_golden.expected_output)
    print("Context (참조 문맥):", first_golden.context)  # 이제 list[str]로 나와야 함
    print("Source File:", first_golden.source_file)
    print("Additional Metadata:", first_golden.additional_metadata)
else:
    print("아직 golden이 생성되지 않았습니다.")

# %%
# 파일 이름은 원하시는 대로 수정 가능합니다.
file_name = "goyang_library_qa_reasoning_and_multi_hop"
directory = "./synthetic_data"

if synthesizer.synthetic_goldens:
    synthesizer.save_as(
        file_type='json', 
        directory=directory, 
        file_name=file_name
    )
    print(f"💾 저장 완료: {directory}/{file_name}.json")
else:
    print("❌ 저장할 데이터가 없습니다.")
